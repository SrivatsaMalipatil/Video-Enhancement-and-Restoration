# %% [markdown]
# ## Step 0: Set up environment

# %%
import os, random, datetime
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import imageio
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from IPython.display import Image
from google.colab import files

# %%
random.seed(17)
np.random.seed(17)
torch.manual_seed(17)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
from nerfmm.utils.pos_enc import encode_position
from nerfmm.utils.volume_op import volume_rendering, volume_sampling_ndc
from nerfmm.utils.comp_ray_dir import comp_ray_dir_cam_fxfy

# utlities
from nerfmm.utils.training_utils import mse2psnr
from nerfmm.utils.lie_group_helper import convert3x4_4x4

# %%
# get prepared example scenes
# !wget https://www.robots.ox.ac.uk/~ryan/nerfmm2021/nerfmm_colab_data.tar.gz

# extract and clean storage
# !tar xzf nerfmm_colab_data.tar.gz
# !rm nerfmm_colab_data.tar.gz
# Out:
# --2024-08-11 07:01:23--  https://www.robots.ox.ac.uk/~ryan/nerfmm2021/nerfmm_colab_data.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25803698 (25M) [application/x-gzip]
# Saving to: ‘nerfmm_colab_data.tar.gz’
#
# nerfmm_colab_data.t 100%[===================>]  24.61M  84.7MB/s    in 0.3s
#
# 2024-08-11 07:01:23 (84.7 MB/s) - ‘nerfmm_colab_data.tar.gz’ saved [25803698/25803698]

# %%
scene_name = input('Pick a scene: (llff_flower / llff_leaves / desk / upload) ')
print('Selected scene: ', scene_name)
if scene_name in ['llff_flower', 'llff_leaves', 'desk']:
    image_dir = os.path.join('nerfmm_colab_data', scene_name)
elif scene_name == 'upload':
    try:
        # !rm -rf 'custom_upload'

        uploaded = files.upload()
        up_file_name = list(uploaded.keys())[0]
        print('Uploaded file "{name}" with size ~{length} MB'.format(name=up_file_name, length=len(uploaded[up_file_name])/1e6))

        # !mv $up_file_name 'custom_upload.zip'
        # !unzip 'custom_upload.zip' -d 'custom_upload'
        # !rm 'custom_upload.zip'
        image_dir = os.path.join('custom_upload', os.listdir('custom_upload')[0])
        print('Upload and unzip done.')
    except:
        print('Seems like upload failed. Please retry.')
else:
    scene_name = 'llff_flower'
    image_dir = os.path.join('nerfmm_colab_data', scene_name)
    print('Unknown scene name. Using llff_flower scene.')
# Out:
# Pick a scene: (llff_flower / llff_leaves / desk / upload) llff_flower
# Selected scene:  llff_flower

# %% [markdown]
# ## Step 1b: Load images

# %%
def load_imgs(image_dir):
    img_names = np.array(sorted(os.listdir(image_dir)))  # all image names
    img_paths = [os.path.join(image_dir, n) for n in img_names]
    N_imgs = len(img_paths)

    img_list = []
    for p in img_paths:
        img = imageio.imread(p)[:, :, :3]  # (H, W, 3) np.uint8
        img_list.append(img)
    img_list = np.stack(img_list)  # (N, H, W, 3)
    img_list = torch.from_numpy(img_list).float() / 255  # (N, H, W, 3) torch.float32
    H, W = img_list.shape[1], img_list.shape[2]

    results = {
        'imgs': img_list,  # (N, H, W, 3) torch.float32
        'img_names': img_names,  # (N, )
        'N_imgs': N_imgs,
        'H': H,
        'W': W,
    }
    return results

image_data = load_imgs(image_dir)
imgs = image_data['imgs']  # (N, H, W, 3) torch.float32

N_IMGS = image_data['N_imgs']
H = image_data['H']
W = image_data['W']

print('Loaded {0} imgs, resolution {1} x {2}'.format(N_IMGS, H, W))
print(imgs.shape)
plt.imshow(imgs[0])
# Out:
# <ipython-input-9-b5babcb90bd2>:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(p)[:, :, :3]  # (H, W, 3) np.uint8
# Loaded 34 imgs, resolution 756 x 1008
# torch.Size([34, 756, 1008, 3])

# %% [markdown]
# ## Step 2a: Define learnable FOCALS
#
# We initialise $f_x = W$ and $f_y = H$.

# %%
class LearnFocal(nn.Module):
    def __init__(self, H, W, req_grad):
        super(LearnFocal, self).__init__()
        self.H = H
        self.W = W
        self.fx = nn.Parameter(torch.tensor(1.0, dtype=torch.float32), requires_grad=req_grad)  # (1, )
        self.fy = nn.Parameter(torch.tensor(1.0, dtype=torch.float32), requires_grad=req_grad)  # (1, )

    def forward(self):
        # order = 2, check our supplementary.
        fxfy = torch.stack([self.fx**2 * self.W, self.fy**2 * self.H])
        return fxfy

# %% [markdown]
# ## Step 2b: Define learnable POSES

# %%
def vec2skew(v):
    """
    :param v:  (3, ) torch tensor
    :return:   (3, 3)
    """
    zero = torch.zeros(1, dtype=torch.float32, device=v.device)
    skew_v0 = torch.cat([ zero,    -v[2:3],   v[1:2]])  # (3, 1)
    skew_v1 = torch.cat([ v[2:3],   zero,    -v[0:1]])
    skew_v2 = torch.cat([-v[1:2],   v[0:1],   zero])
    skew_v = torch.stack([skew_v0, skew_v1, skew_v2], dim=0)  # (3, 3)
    return skew_v  # (3, 3)


def Exp(r):
    """so(3) vector to SO(3) matrix
    :param r: (3, ) axis-angle, torch tensor
    :return:  (3, 3)
    """
    skew_r = vec2skew(r)  # (3, 3)
    norm_r = r.norm() + 1e-15
    eye = torch.eye(3, dtype=torch.float32, device=r.device)
    R = eye + (torch.sin(norm_r) / norm_r) * skew_r + ((1 - torch.cos(norm_r)) / norm_r**2) * (skew_r @ skew_r)
    return R


def make_c2w(r, t):
    """
    :param r:  (3, ) axis-angle             torch tensor
    :param t:  (3, ) translation vector     torch tensor
    :return:   (4, 4)
    """
    R = Exp(r)  # (3, 3)
    c2w = torch.cat([R, t.unsqueeze(1)], dim=1)  # (3, 4)
    c2w = convert3x4_4x4(c2w)  # (4, 4)
    return c2w


class LearnPose(nn.Module):
    def __init__(self, num_cams, learn_R, learn_t):
        super(LearnPose, self).__init__()
        self.num_cams = num_cams
        self.r = nn.Parameter(torch.zeros(size=(num_cams, 3), dtype=torch.float32), requires_grad=learn_R)  # (N, 3)
        self.t = nn.Parameter(torch.zeros(size=(num_cams, 3), dtype=torch.float32), requires_grad=learn_t)  # (N, 3)

    def forward(self, cam_id):
        r = self.r[cam_id]  # (3, ) axis-angle
        t = self.t[cam_id]  # (3, )
        c2w = make_c2w(r, t)  # (4, 4)
        return c2w

# %% [markdown]
# ## Step 2c: Define a tiny NeRF

# %%
class TinyNerf(nn.Module):
    def __init__(self, pos_in_dims, dir_in_dims, D):
        """
        :param pos_in_dims: scalar, number of channels of encoded positions
        :param dir_in_dims: scalar, number of channels of encoded directions
        :param D:           scalar, number of hidden dimensions
        """
        super(TinyNerf, self).__init__()

        self.pos_in_dims = pos_in_dims
        self.dir_in_dims = dir_in_dims

        self.layers0 = nn.Sequential(
            nn.Linear(pos_in_dims, D), nn.ReLU(),
            nn.Linear(D, D), nn.ReLU(),
            nn.Linear(D, D), nn.ReLU(),
            nn.Linear(D, D), nn.ReLU(),
        )

        self.fc_density = nn.Linear(D, 1)
        self.fc_feature = nn.Linear(D, D)
        self.rgb_layers = nn.Sequential(nn.Linear(D + dir_in_dims, D//2), nn.ReLU())
        self.fc_rgb = nn.Linear(D//2, 3)

        self.fc_density.bias.data = torch.tensor([0.1]).float()
        self.fc_rgb.bias.data = torch.tensor([0.02, 0.02, 0.02]).float()

    def forward(self, pos_enc, dir_enc):
        """
        :param pos_enc: (H, W, N_sample, pos_in_dims) encoded positions
        :param dir_enc: (H, W, N_sample, dir_in_dims) encoded directions
        :return: rgb_density (H, W, N_sample, 4)
        """
        x = self.layers0(pos_enc)  # (H, W, N_sample, D)
        density = self.fc_density(x)  # (H, W, N_sample, 1)

        feat = self.fc_feature(x)  # (H, W, N_sample, D)
        x = torch.cat([feat, dir_enc], dim=3)  # (H, W, N_sample, D+dir_in_dims)
        x = self.rgb_layers(x)  # (H, W, N_sample, D/2)
        rgb = self.fc_rgb(x)  # (H, W, N_sample, 3)

        rgb_den = torch.cat([rgb, density], dim=3)  # (H, W, N_sample, 4)
        return rgb_den

# %% [markdown]
# ## Step 3: Training pipeline

# %% [markdown]
# ### Set ray parameters

# %%
class RayParameters():
    def __init__(self):
      self.NEAR, self.FAR = 0.0, 1.0  # ndc near far
      self.N_SAMPLE = 128  # samples per ray
      self.POS_ENC_FREQ = 10  # positional encoding freq for location
      self.DIR_ENC_FREQ = 4 # positional encoding freq for direction

ray_params = RayParameters()

# %% [markdown]
# ### Define training function

# %%
def model_render_image(c2w, rays_cam, t_vals, ray_params, H, W, fxfy, nerf_model,
                       perturb_t, sigma_noise_std):
    """
    :param c2w:         (4, 4)                  pose to transform ray direction from cam to world.
    :param rays_cam:    (someH, someW, 3)       ray directions in camera coordinate, can be random selected
                                                rows and cols, or some full rows, or an entire image.
    :param t_vals:      (N_samples)             sample depth along a ray.
    :param perturb_t:   True/False              perturb t values.
    :param sigma_noise_std: float               add noise to raw density predictions (sigma).
    :return:            (someH, someW, 3)       volume rendered images for the input rays.
    """
    # KEY 2: sample the 3D volume using estimated poses and intrinsics online.
    # (H, W, N_sample, 3), (H, W, 3), (H, W, N_sam)
    sample_pos, _, ray_dir_world, t_vals_noisy = volume_sampling_ndc(c2w, rays_cam, t_vals, ray_params.NEAR,
                                                                     ray_params.FAR, H, W, fxfy, perturb_t)

    # encode position: (H, W, N_sample, (2L+1)*C = 63)
    pos_enc = encode_position(sample_pos, levels=ray_params.POS_ENC_FREQ, inc_input=True)

    # encode direction: (H, W, N_sample, (2L+1)*C = 27)
    ray_dir_world = F.normalize(ray_dir_world, p=2, dim=2)  # (H, W, 3)
    dir_enc = encode_position(ray_dir_world, levels=ray_params.DIR_ENC_FREQ, inc_input=True)  # (H, W, 27)
    dir_enc = dir_enc.unsqueeze(2).expand(-1, -1, ray_params.N_SAMPLE, -1)  # (H, W, N_sample, 27)

    # inference rgb and density using position and direction encoding.
    rgb_density = nerf_model(pos_enc, dir_enc)  # (H, W, N_sample, 4)

    render_result = volume_rendering(rgb_density, t_vals_noisy, sigma_noise_std, rgb_act_fn=torch.sigmoid)
    rgb_rendered = render_result['rgb']  # (H, W, 3)
    depth_map = render_result['depth_map']  # (H, W)

    result = {
        'rgb': rgb_rendered,  # (H, W, 3)
        'depth_map': depth_map,  # (H, W)
    }

    return result


def train_one_epoch(imgs, H, W, ray_params, opt_nerf, opt_focal,
                    opt_pose, nerf_model, focal_net, pose_param_net):
    nerf_model.train()
    focal_net.train()
    pose_param_net.train()

    t_vals = torch.linspace(ray_params.NEAR, ray_params.FAR, ray_params.N_SAMPLE, device='cuda')  # (N_sample,) sample position
    L2_loss_epoch = []

    # shuffle the training imgs
    ids = np.arange(N_IMGS)
    np.random.shuffle(ids)

    for i in ids:
        fxfy = focal_net()

        # KEY 1: compute ray directions using estimated intrinsics online.
        ray_dir_cam = comp_ray_dir_cam_fxfy(H, W, fxfy[0], fxfy[1])
        img = imgs[i].to('cuda')  # (H, W, 4)
        c2w = pose_param_net(i)  # (4, 4)

        # sample 32x32 pixel on an image and their rays for training.
        r_id = torch.randperm(H, device='cuda')[:32]  # (N_select_rows)
        c_id = torch.randperm(W, device='cuda')[:32]  # (N_select_cols)
        ray_selected_cam = ray_dir_cam[r_id][:, c_id]  # (N_select_rows, N_select_cols, 3)
        img_selected = img[r_id][:, c_id]  # (N_select_rows, N_select_cols, 3)

        # render an image using selected rays, pose, sample intervals, and the network
        render_result = model_render_image(c2w, ray_selected_cam, t_vals, ray_params,
                                           H, W, fxfy, nerf_model, perturb_t=True, sigma_noise_std=0.0)
        rgb_rendered = render_result['rgb']  # (N_select_rows, N_select_cols, 3)
        L2_loss = F.mse_loss(rgb_rendered, img_selected)  # loss for one image

        L2_loss.backward()
        opt_nerf.step()
        opt_focal.step()
        opt_pose.step()
        opt_nerf.zero_grad()
        opt_focal.zero_grad()
        opt_pose.zero_grad()

        L2_loss_epoch.append(L2_loss)

    L2_loss_epoch_mean = torch.stack(L2_loss_epoch).mean().item()
    return L2_loss_epoch_mean

# %% [markdown]
# ### Define evaluation function

# %%
def render_novel_view(c2w, H, W, fxfy, ray_params, nerf_model):
    nerf_model.eval()

    ray_dir_cam = comp_ray_dir_cam_fxfy(H, W, fxfy[0], fxfy[1])
    t_vals = torch.linspace(ray_params.NEAR, ray_params.FAR, ray_params.N_SAMPLE, device='cuda')  # (N_sample,) sample position

    c2w = c2w.to('cuda')  # (4, 4)

    # split an image to rows when the input image resolution is high
    rays_dir_cam_split_rows = ray_dir_cam.split(10, dim=0)  # input 10 rows each time
    rendered_img = []
    rendered_depth = []
    for rays_dir_rows in rays_dir_cam_split_rows:
        render_result = model_render_image(c2w, rays_dir_rows, t_vals, ray_params,
                                           H, W, fxfy, nerf_model,
                                           perturb_t=False, sigma_noise_std=0.0)
        rgb_rendered_rows = render_result['rgb']  # (num_rows_eval_img, W, 3)
        depth_map = render_result['depth_map']  # (num_rows_eval_img, W)

        rendered_img.append(rgb_rendered_rows)
        rendered_depth.append(depth_map)

    # combine rows to an image
    rendered_img = torch.cat(rendered_img, dim=0)  # (H, W, 3)
    rendered_depth = torch.cat(rendered_depth, dim=0)  # (H, W)
    return rendered_img, rendered_depth

# %% [markdown]
# ## Step 4: Actual training ⚽

# %%
N_EPOCH = 5000 # set to 1000 to get slightly better results.
EVAL_INTERVAL = 50  # render an image to visualise for every this interval.

# Initialise all trainabled parameters
focal_net = LearnFocal(H, W, req_grad=True).cuda()
pose_param_net = LearnPose(num_cams=N_IMGS, learn_R=True, learn_t=True).cuda()

# Get a tiny NeRF model. Hidden dimension set to 128
nerf_model = TinyNerf(pos_in_dims=63, dir_in_dims=27, D=128).cuda()

# Set lr and scheduler: these are just stair-case exponantial decay lr schedulers.
opt_nerf = torch.optim.Adam(nerf_model.parameters(), lr=0.001)
opt_focal = torch.optim.Adam(focal_net.parameters(), lr=0.001)
opt_pose = torch.optim.Adam(pose_param_net.parameters(), lr=0.001)

from torch.optim.lr_scheduler import MultiStepLR
scheduler_nerf = MultiStepLR(opt_nerf, milestones=list(range(0, 10000, 10)), gamma=0.9954)
scheduler_focal = MultiStepLR(opt_focal, milestones=list(range(0, 10000, 100)), gamma=0.9)
scheduler_pose = MultiStepLR(opt_pose, milestones=list(range(0, 10000, 100)), gamma=0.9)

# Set tensorboard writer
writer = SummaryWriter(log_dir=os.path.join('logs', scene_name, str(datetime.datetime.now().strftime('%y%m%d_%H%M%S'))))

# Store poses to visualise them later
pose_history = []

# Training
print('Training... Check results in the tensorboard above.')
for epoch_i in tqdm(range(N_EPOCH), desc='Training'):
    L2_loss = train_one_epoch(imgs, H, W, ray_params, opt_nerf, opt_focal,
                              opt_pose, nerf_model, focal_net, pose_param_net)
    train_psnr = mse2psnr(L2_loss)

    writer.add_scalar('train/psnr', train_psnr, epoch_i)

    fxfy = focal_net()
    print('epoch {0:4d} Training PSNR {1:.3f}, estimated fx {2:.1f} fy {3:.1f}'.format(epoch_i, train_psnr, fxfy[0], fxfy[1]))

    scheduler_nerf.step()
    scheduler_focal.step()
    scheduler_pose.step()

    learned_c2ws = torch.stack([pose_param_net(i) for i in range(N_IMGS)])  # (N, 4, 4)
    pose_history.append(learned_c2ws[:, :3, 3])  # (N, 3) only store positions as we vis in 2D.

    with torch.no_grad():
        if (epoch_i+1) % EVAL_INTERVAL == 0:
            eval_c2w = torch.eye(4, dtype=torch.float32)  # (4, 4)
            fxfy = focal_net()
            rendered_img, rendered_depth = render_novel_view(eval_c2w, H, W, fxfy, ray_params, nerf_model)
            writer.add_image('eval/img', rendered_img.permute(2, 0, 1), global_step=epoch_i)
            writer.add_image('eval/depth', rendered_depth.unsqueeze(0), global_step=epoch_i)

pose_history = torch.stack(pose_history).detach().cpu().numpy()  # (N_epoch, N_img, 3)
print('Training finished.')
# Out:
# Training... Check results in the tensorboard above.
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# epoch    0 Training PSNR 12.070, estimated fx 1009.0 fy 757.9
# epoch    1 Training PSNR 12.769, estimated fx 1011.4 fy 763.7
# epoch    2 Training PSNR 12.934, estimated fx 1011.9 fy 774.0
# epoch    3 Training PSNR 13.154, estimated fx 1001.6 fy 793.4
# epoch    4 Training PSNR 13.222, estimated fx 1014.3 fy 797.7
# epoch    5 Training PSNR 13.317, estimated fx 1042.6 fy 822.9
# epoch    6 Training PSNR 13.247, estimated fx 1070.0 fy 839.8
# epoch    7 Training PSNR 13.473, estimated fx 1114.0 fy 838.7
# epoch    8 Training PSNR 13.603, estimated fx 1164.4 fy 851.2
# epoch    9 Training PSNR 13.686, estimated fx 1233.0 fy 870.6
# epoch   10 Training PSNR 13.925, estimated fx 1294.1 fy 895.7
# epoch   11 Training PSNR 14.185, estimated fx 1375.3 fy 927.7
# epoch   12 Training PSNR 14.510, estimated fx 1448.1 fy 954.7
# epoch   13 Training PSNR 14.753, estimated fx 1521.6 fy 978.9
# epoch   14 Training PSNR 15.011, estimated fx 1534.1 fy 989.1
# epoch   15 Training PSNR 15.425, estimated fx 1572.8 fy 995.7
# epoch   16 Training PSNR 15.380, estimated fx 1547.8 fy 995.2
# epoch   17 Training PSNR 15.701, estimated fx 1558.4 fy 998.5
# epoch   18 Training PSNR 15.712, estimated fx 1542.7 fy 1013.3
# epoch   19 Training PSNR 15.765, estimated fx 1538.3 fy 1009.6
# epoch   20 Training PSNR 15.889, estimated fx 1523.2 fy 1001.7
# epoch   21 Training PSNR 16.036, estimated fx 1521.7 fy 996.8
# epoch   22 Training PSNR 16.001, estimated fx 1521.4 fy 997.1
# epoch   23 Training PSNR 16.016, estimated fx 1523.1 fy 994.5
# epoch   24 Training PSNR 16.169, estimated fx 1495.9 fy 996.0
# epoch   25 Training PSNR 16.226, estimated fx 1494.7 fy 986.8
# epoch   26 Training PSNR 16.268, estimated fx 1490.4 fy 985.2
# epoch   27 Training PSNR 16.388, estimated fx 1476.4 fy 979.1
# epoch   28 Training PSNR 16.369, estimated fx 1487.6 fy 967.1
# epoch   29 Training PSNR 16.343, estimated fx 1467.0 fy 961.7
# epoch   30 Training PSNR 16.440, estimated fx 1468.8 fy 955.4
# epoch   31 Training PSNR 16.674, estimated fx 1469.1 fy 960.8
# epoch   32 Training PSNR 16.618, estimated fx 1461.1 fy 960.3
# epoch   33 Training PSNR 16.718, estimated fx 1456.7 fy 955.8
# epoch   34 Training PSNR 16.642, estimated fx 1439.5 fy 950.4
# epoch   35 Training PSNR 16.800, estimated fx 1438.4 fy 953.6
# epoch   36 Training PSNR 16.670, estimated fx 1444.3 fy 938.1
# epoch   37 Training PSNR 16.866, estimated fx 1421.8 fy 947.3
# epoch   38 Training PSNR 17.018, estimated fx 1429.8 fy 940.4
# epoch   39 Training PSNR 16.893, estimated fx 1421.0 fy 935.5
# epoch   40 Training PSNR 16.997, estimated fx 1423.1 fy 926.1
# epoch   41 Training PSNR 17.081, estimated fx 1413.0 fy 939.7
# epoch   42 Training PSNR 17.221, estimated fx 1410.2 fy 933.4
# epoch   43 Training PSNR 17.221, estimated fx 1410.4 fy 923.6
# epoch   44 Training PSNR 17.091, estimated fx 1418.6 fy 922.7
# epoch   45 Training PSNR 17.090, estimated fx 1395.0 fy 919.0
# epoch   46 Training PSNR 17.162, estimated fx 1397.8 fy 919.6
# epoch   47 Training PSNR 17.369, estimated fx 1391.1 fy 922.5
# epoch   48 Training PSNR 17.448, estimated fx 1383.5 fy 913.4
# epoch   49 Training PSNR 17.318, estimated fx 1396.3 fy 913.1
# epoch   50 Training PSNR 17.418, estimated fx 1373.3 fy 919.0
# epoch   51 Training PSNR 17.457, estimated fx 1387.0 fy 917.3
# epoch   52 Training PSNR 17.401, estimated fx 1364.0 fy 914.9
# epoch   53 Training PSNR 17.429, estimated fx 1373.0 fy 909.2
# epoch   54 Training PSNR 17.354, estimated fx 1361.7 fy 899.7
# epoch   55 Training PSNR 17.308, estimated fx 1359.7 fy 907.3
# epoch   56 Training PSNR 17.569, estimated fx 1352.9 fy 900.8
# epoch   57 Training PSNR 17.622, estimated fx 1349.2 fy 900.6
# epoch   58 Training PSNR 17.561, estimated fx 1349.8 fy 898.2
# epoch   59 Training PSNR 17.545, estimated fx 1345.3 fy 897.8
# epoch   60 Training PSNR 17.629, estimated fx 1337.7 fy 894.5
# epoch   61 Training PSNR 17.671, estimated fx 1335.4 fy 891.7
# epoch   62 Training PSNR 17.746, estimated fx 1329.9 fy 892.5
# epoch   63 Training PSNR 17.844, estimated fx 1326.5 fy 888.7
# epoch   64 Training PSNR 17.977, estimated fx 1328.9 fy 883.8
# epoch   65 Training PSNR 17.698, estimated fx 1320.8 fy 889.2
# epoch   66 Training PSNR 17.801, estimated fx 1321.8 fy 884.8
# epoch   67 Training PSNR 17.743, estimated fx 1311.8 fy 880.7
# epoch   68 Training PSNR 17.901, estimated fx 1314.6 fy 883.4
# epoch   69 Training PSNR 17.801, estimated fx 1307.7 fy 876.9
# epoch   70 Training PSNR 17.910, estimated fx 1309.8 fy 870.8
# epoch   71 Training PSNR 17.804, estimated fx 1307.5 fy 870.4
# epoch   72 Training PSNR 18.082, estimated fx 1297.7 fy 872.3
# epoch   73 Training PSNR 17.878, estimated fx 1291.7 fy 873.0
# epoch   74 Training PSNR 17.919, estimated fx 1288.6 fy 871.2
# epoch   75 Training PSNR 17.918, estimated fx 1288.9 fy 870.5
# epoch   76 Training PSNR 18.072, estimated fx 1285.9 fy 865.7
# epoch   77 Training PSNR 18.083, estimated fx 1283.6 fy 866.9
# epoch   78 Training PSNR 17.951, estimated fx 1282.8 fy 868.7
# epoch   79 Training PSNR 18.014, estimated fx 1272.8 fy 860.6
# epoch   80 Training PSNR 18.089, estimated fx 1274.3 fy 866.4
# epoch   81 Training PSNR 17.966, estimated fx 1270.7 fy 860.5
# epoch   82 Training PSNR 17.984, estimated fx 1269.4 fy 859.1
# epoch   83 Training PSNR 18.206, estimated fx 1258.3 fy 850.1
# epoch   84 Training PSNR 18.231, estimated fx 1266.8 fy 858.6
# epoch   85 Training PSNR 18.220, estimated fx 1250.9 fy 856.1
# epoch   86 Training PSNR 18.150, estimated fx 1266.2 fy 847.4
# epoch   87 Training PSNR 18.018, estimated fx 1251.5 fy 857.0
# epoch   88 Training PSNR 17.927, estimated fx 1254.6 fy 852.4
# epoch   89 Training PSNR 18.065, estimated fx 1244.7 fy 848.8
# epoch   90 Training PSNR 18.411, estimated fx 1242.1 fy 851.3
# epoch   91 Training PSNR 18.128, estimated fx 1239.0 fy 844.8
# epoch   92 Training PSNR 18.209, estimated fx 1231.1 fy 845.1
# epoch   93 Training PSNR 18.249, estimated fx 1241.2 fy 842.2
# epoch   94 Training PSNR 18.486, estimated fx 1230.3 fy 839.4
# epoch   95 Training PSNR 18.593, estimated fx 1240.6 fy 836.8
# epoch   96 Training PSNR 18.341, estimated fx 1226.4 fy 838.8
# epoch   97 Training PSNR 18.387, estimated fx 1232.9 fy 837.5
# epoch   98 Training PSNR 18.319, estimated fx 1218.0 fy 842.8
# epoch   99 Training PSNR 18.217, estimated fx 1230.3 fy 829.8
# epoch  100 Training PSNR 18.211, estimated fx 1216.8 fy 837.1
# epoch  101 Training PSNR 18.621, estimated fx 1222.8 fy 832.5
# epoch  102 Training PSNR 18.618, estimated fx 1213.1 fy 838.5
# epoch  103 Training PSNR 18.674, estimated fx 1217.1 fy 827.4
# epoch  104 Training PSNR 18.714, estimated fx 1206.1 fy 839.5
# epoch  105 Training PSNR 18.425, estimated fx 1222.0 fy 825.8
# epoch  106 Training PSNR 18.322, estimated fx 1206.6 fy 831.4
# epoch  107 Training PSNR 18.511, estimated fx 1212.6 fy 826.7
# epoch  108 Training PSNR 18.661, estimated fx 1204.6 fy 825.2
# epoch  109 Training PSNR 18.746, estimated fx 1207.2 fy 827.3
# epoch  110 Training PSNR 18.837, estimated fx 1196.3 fy 829.7
# epoch  111 Training PSNR 18.474, estimated fx 1203.9 fy 826.9
# epoch  112 Training PSNR 18.656, estimated fx 1187.4 fy 821.2
# epoch  113 Training PSNR 18.654, estimated fx 1214.7 fy 821.9
# epoch  114 Training PSNR 18.401, estimated fx 1181.9 fy 827.9
# epoch  115 Training PSNR 18.717, estimated fx 1205.6 fy 816.1
# epoch  116 Training PSNR 18.646, estimated fx 1182.3 fy 830.0
# epoch  117 Training PSNR 18.470, estimated fx 1194.9 fy 815.2
# epoch  118 Training PSNR 18.603, estimated fx 1185.2 fy 817.7
# epoch  119 Training PSNR 18.739, estimated fx 1193.8 fy 818.3
# epoch  120 Training PSNR 18.876, estimated fx 1182.0 fy 817.5
# epoch  121 Training PSNR 18.896, estimated fx 1192.4 fy 817.5
# epoch  122 Training PSNR 18.648, estimated fx 1175.5 fy 818.2
# epoch  123 Training PSNR 18.697, estimated fx 1189.5 fy 820.3
# epoch  124 Training PSNR 18.874, estimated fx 1167.5 fy 821.5
# epoch  125 Training PSNR 18.867, estimated fx 1185.1 fy 815.2
# epoch  126 Training PSNR 19.049, estimated fx 1164.1 fy 823.3
# epoch  127 Training PSNR 18.749, estimated fx 1181.3 fy 807.9
# epoch  128 Training PSNR 18.972, estimated fx 1164.4 fy 821.0
# epoch  129 Training PSNR 18.901, estimated fx 1177.1 fy 815.3
# epoch  130 Training PSNR 19.007, estimated fx 1166.1 fy 824.3
# epoch  131 Training PSNR 18.926, estimated fx 1178.2 fy 806.4
# epoch  132 Training PSNR 18.754, estimated fx 1157.5 fy 820.5
# epoch  133 Training PSNR 19.000, estimated fx 1172.3 fy 809.3
# epoch  134 Training PSNR 18.872, estimated fx 1155.1 fy 813.3
# epoch  135 Training PSNR 19.000, estimated fx 1168.6 fy 808.6
# epoch  136 Training PSNR 18.773, estimated fx 1154.3 fy 810.3
# epoch  137 Training PSNR 18.937, estimated fx 1157.4 fy 808.3
# epoch  138 Training PSNR 18.894, estimated fx 1157.1 fy 810.1
# epoch  139 Training PSNR 18.785, estimated fx 1158.1 fy 806.4
# epoch  140 Training PSNR 18.681, estimated fx 1146.9 fy 808.4
# epoch  141 Training PSNR 18.840, estimated fx 1154.0 fy 806.7
# epoch  142 Training PSNR 19.018, estimated fx 1143.1 fy 814.4
# epoch  143 Training PSNR 19.048, estimated fx 1156.6 fy 797.8
# epoch  144 Training PSNR 18.999, estimated fx 1139.4 fy 812.4
# epoch  145 Training PSNR 19.090, estimated fx 1153.7 fy 796.4
# epoch  146 Training PSNR 18.944, estimated fx 1138.5 fy 811.3
# epoch  147 Training PSNR 18.908, estimated fx 1150.5 fy 796.5
# epoch  148 Training PSNR 19.033, estimated fx 1137.1 fy 805.2
# epoch  149 Training PSNR 19.255, estimated fx 1146.1 fy 796.5
# epoch  150 Training PSNR 19.173, estimated fx 1131.2 fy 803.6
# epoch  151 Training PSNR 18.938, estimated fx 1143.8 fy 794.2
# epoch  152 Training PSNR 19.166, estimated fx 1130.1 fy 803.2
# epoch  153 Training PSNR 19.144, estimated fx 1136.5 fy 797.5
# epoch  154 Training PSNR 18.956, estimated fx 1126.6 fy 803.7
# epoch  155 Training PSNR 19.058, estimated fx 1138.6 fy 791.2
# epoch  156 Training PSNR 18.861, estimated fx 1117.9 fy 805.6
# epoch  157 Training PSNR 19.099, estimated fx 1137.8 fy 791.7
# epoch  158 Training PSNR 19.036, estimated fx 1122.3 fy 796.1
# epoch  159 Training PSNR 19.121, estimated fx 1131.9 fy 793.6
# epoch  160 Training PSNR 19.312, estimated fx 1120.5 fy 793.6
# epoch  161 Training PSNR 19.285, estimated fx 1127.1 fy 789.8
# epoch  162 Training PSNR 18.838, estimated fx 1122.2 fy 791.5
# epoch  163 Training PSNR 18.989, estimated fx 1126.1 fy 791.0
# epoch  164 Training PSNR 19.054, estimated fx 1120.3 fy 791.1
# epoch  165 Training PSNR 19.034, estimated fx 1115.8 fy 788.0
# epoch  166 Training PSNR 19.356, estimated fx 1121.9 fy 789.5
# epoch  167 Training PSNR 19.194, estimated fx 1110.4 fy 788.5
# epoch  168 Training PSNR 19.002, estimated fx 1113.1 fy 786.3
# epoch  169 Training PSNR 19.182, estimated fx 1114.0 fy 791.3
# epoch  170 Training PSNR 19.172, estimated fx 1111.2 fy 785.5
# epoch  171 Training PSNR 19.224, estimated fx 1105.9 fy 789.2
# epoch  172 Training PSNR 19.278, estimated fx 1112.9 fy 786.2
# epoch  173 Training PSNR 18.994, estimated fx 1104.3 fy 792.7
# epoch  174 Training PSNR 19.303, estimated fx 1108.6 fy 781.1
# epoch  175 Training PSNR 19.117, estimated fx 1103.7 fy 785.3
# epoch  176 Training PSNR 19.325, estimated fx 1104.7 fy 783.6
# epoch  177 Training PSNR 19.124, estimated fx 1095.8 fy 785.2
# epoch  178 Training PSNR 19.164, estimated fx 1099.5 fy 783.7
# epoch  179 Training PSNR 19.344, estimated fx 1098.7 fy 782.4
# epoch  180 Training PSNR 19.237, estimated fx 1099.6 fy 782.7
# epoch  181 Training PSNR 19.159, estimated fx 1096.7 fy 778.9
# epoch  182 Training PSNR 19.297, estimated fx 1098.8 fy 781.3
# epoch  183 Training PSNR 19.180, estimated fx 1090.5 fy 781.5
# epoch  184 Training PSNR 19.284, estimated fx 1097.1 fy 777.3
# epoch  185 Training PSNR 19.460, estimated fx 1089.1 fy 779.9
# epoch  186 Training PSNR 19.504, estimated fx 1097.7 fy 775.9
# epoch  187 Training PSNR 19.517, estimated fx 1087.1 fy 779.7
# epoch  188 Training PSNR 19.238, estimated fx 1091.5 fy 780.0
# epoch  189 Training PSNR 19.116, estimated fx 1084.7 fy 779.9
# epoch  190 Training PSNR 19.288, estimated fx 1089.3 fy 774.4
# epoch  191 Training PSNR 19.274, estimated fx 1082.5 fy 779.3
# epoch  192 Training PSNR 19.370, estimated fx 1085.1 fy 775.2
# epoch  193 Training PSNR 19.480, estimated fx 1076.1 fy 783.1
# epoch  194 Training PSNR 19.520, estimated fx 1084.7 fy 774.0
# epoch  195 Training PSNR 19.444, estimated fx 1074.7 fy 778.3
# epoch  196 Training PSNR 19.344, estimated fx 1086.6 fy 767.2
# epoch  197 Training PSNR 19.303, estimated fx 1077.9 fy 776.8
# epoch  198 Training PSNR 19.255, estimated fx 1085.2 fy 767.4
# epoch  199 Training PSNR 19.347, estimated fx 1073.4 fy 778.7
# epoch  200 Training PSNR 19.455, estimated fx 1082.6 fy 768.6
# epoch  201 Training PSNR 19.561, estimated fx 1068.9 fy 777.0
# epoch  202 Training PSNR 19.507, estimated fx 1077.9 fy 769.3
# epoch  203 Training PSNR 19.627, estimated fx 1071.6 fy 776.7
# epoch  204 Training PSNR 19.530, estimated fx 1073.0 fy 769.7
# epoch  205 Training PSNR 19.751, estimated fx 1065.9 fy 773.1
# epoch  206 Training PSNR 19.455, estimated fx 1076.2 fy 769.8
# epoch  207 Training PSNR 19.778, estimated fx 1067.4 fy 774.8
# epoch  208 Training PSNR 19.751, estimated fx 1073.6 fy 770.1
# epoch  209 Training PSNR 19.891, estimated fx 1066.8 fy 775.4
# epoch  210 Training PSNR 19.761, estimated fx 1070.6 fy 771.8
# epoch  211 Training PSNR 19.819, estimated fx 1067.2 fy 775.2
# epoch  212 Training PSNR 19.544, estimated fx 1065.7 fy 772.7
# epoch  213 Training PSNR 19.712, estimated fx 1065.8 fy 774.5
# epoch  214 Training PSNR 19.647, estimated fx 1066.2 fy 770.4
# epoch  215 Training PSNR 19.688, estimated fx 1061.2 fy 778.5
# epoch  216 Training PSNR 19.341, estimated fx 1065.5 fy 770.7
# epoch  217 Training PSNR 19.511, estimated fx 1061.4 fy 777.1
# epoch  218 Training PSNR 19.676, estimated fx 1063.0 fy 771.0
# epoch  219 Training PSNR 19.775, estimated fx 1060.2 fy 772.7
# epoch  220 Training PSNR 19.729, estimated fx 1060.4 fy 769.4
# epoch  221 Training PSNR 19.560, estimated fx 1058.9 fy 773.6
# epoch  222 Training PSNR 19.760, estimated fx 1057.3 fy 772.1
# epoch  223 Training PSNR 19.735, estimated fx 1056.5 fy 768.1
# epoch  224 Training PSNR 19.614, estimated fx 1055.2 fy 777.0
# epoch  225 Training PSNR 19.595, estimated fx 1061.1 fy 762.6
# epoch  226 Training PSNR 19.525, estimated fx 1052.4 fy 770.3
# epoch  227 Training PSNR 19.854, estimated fx 1056.5 fy 767.0
# epoch  228 Training PSNR 19.787, estimated fx 1053.8 fy 771.2
# epoch  229 Training PSNR 19.956, estimated fx 1050.7 fy 764.5
# epoch  230 Training PSNR 20.052, estimated fx 1059.7 fy 770.8
# epoch  231 Training PSNR 19.767, estimated fx 1045.1 fy 767.0
# epoch  232 Training PSNR 19.774, estimated fx 1056.2 fy 766.7
# epoch  233 Training PSNR 19.675, estimated fx 1042.3 fy 771.7
# epoch  234 Training PSNR 19.537, estimated fx 1051.9 fy 766.0
# epoch  235 Training PSNR 19.638, estimated fx 1044.3 fy 768.3
# epoch  236 Training PSNR 19.752, estimated fx 1052.3 fy 764.0
# epoch  237 Training PSNR 19.736, estimated fx 1040.1 fy 774.4
# epoch  238 Training PSNR 19.393, estimated fx 1051.9 fy 760.0
# epoch  239 Training PSNR 19.509, estimated fx 1037.7 fy 772.5
# epoch  240 Training PSNR 19.503, estimated fx 1049.6 fy 762.4
# epoch  241 Training PSNR 19.728, estimated fx 1043.7 fy 768.8
# epoch  242 Training PSNR 20.040, estimated fx 1041.7 fy 765.7
# epoch  243 Training PSNR 19.851, estimated fx 1045.6 fy 765.5
# epoch  244 Training PSNR 19.981, estimated fx 1037.9 fy 769.9
# epoch  245 Training PSNR 19.400, estimated fx 1043.4 fy 760.3
# epoch  246 Training PSNR 19.722, estimated fx 1034.5 fy 768.5
# epoch  247 Training PSNR 19.767, estimated fx 1043.4 fy 761.7
# epoch  248 Training PSNR 19.835, estimated fx 1037.5 fy 771.1
# epoch  249 Training PSNR 19.297, estimated fx 1037.9 fy 763.0
# epoch  250 Training PSNR 19.875, estimated fx 1029.6 fy 767.5
# epoch  251 Training PSNR 20.016, estimated fx 1041.9 fy 762.0
# epoch  252 Training PSNR 20.110, estimated fx 1030.5 fy 770.6
# epoch  253 Training PSNR 19.830, estimated fx 1039.3 fy 760.5
# epoch  254 Training PSNR 19.747, estimated fx 1028.3 fy 770.5
# epoch  255 Training PSNR 19.764, estimated fx 1035.6 fy 759.0
# epoch  256 Training PSNR 19.767, estimated fx 1027.8 fy 772.0
# epoch  257 Training PSNR 19.742, estimated fx 1034.6 fy 760.2
# epoch  258 Training PSNR 19.800, estimated fx 1031.5 fy 767.5
# epoch  259 Training PSNR 20.072, estimated fx 1028.3 fy 759.8
# epoch  260 Training PSNR 19.910, estimated fx 1028.3 fy 763.9
# epoch  261 Training PSNR 19.988, estimated fx 1027.0 fy 764.4
# epoch  262 Training PSNR 19.902, estimated fx 1024.4 fy 765.3
# epoch  263 Training PSNR 19.941, estimated fx 1025.7 fy 764.1
# epoch  264 Training PSNR 20.123, estimated fx 1025.2 fy 765.2
# epoch  265 Training PSNR 20.011, estimated fx 1024.2 fy 762.6
# epoch  266 Training PSNR 19.812, estimated fx 1023.3 fy 762.3
# epoch  267 Training PSNR 19.898, estimated fx 1023.8 fy 761.5
# epoch  268 Training PSNR 19.742, estimated fx 1021.6 fy 763.2
# epoch  269 Training PSNR 19.859, estimated fx 1023.8 fy 761.2
# epoch  270 Training PSNR 19.789, estimated fx 1018.7 fy 763.7
# epoch  271 Training PSNR 19.752, estimated fx 1023.0 fy 760.4
# epoch  272 Training PSNR 20.058, estimated fx 1017.8 fy 761.8
# epoch  273 Training PSNR 20.183, estimated fx 1019.2 fy 763.2
# epoch  274 Training PSNR 20.449, estimated fx 1020.0 fy 759.8
# epoch  275 Training PSNR 20.381, estimated fx 1014.5 fy 762.8
# epoch  276 Training PSNR 20.020, estimated fx 1021.5 fy 762.3
# epoch  277 Training PSNR 20.198, estimated fx 1016.9 fy 760.1
# epoch  278 Training PSNR 19.732, estimated fx 1021.5 fy 761.3
# epoch  279 Training PSNR 19.690, estimated fx 1017.0 fy 764.3
# epoch  280 Training PSNR 20.041, estimated fx 1014.8 fy 761.0
# epoch  281 Training PSNR 20.190, estimated fx 1018.8 fy 758.2
# epoch  282 Training PSNR 19.997, estimated fx 1009.4 fy 758.9
# epoch  283 Training PSNR 19.999, estimated fx 1016.4 fy 760.8
# epoch  284 Training PSNR 19.924, estimated fx 1006.6 fy 756.9
# epoch  285 Training PSNR 19.659, estimated fx 1017.4 fy 755.8
# epoch  286 Training PSNR 19.681, estimated fx 1004.0 fy 758.0
# epoch  287 Training PSNR 19.610, estimated fx 1014.4 fy 757.0
# epoch  288 Training PSNR 19.540, estimated fx 1007.9 fy 754.9
# epoch  289 Training PSNR 19.918, estimated fx 1013.7 fy 754.1
# epoch  290 Training PSNR 19.957, estimated fx 1004.1 fy 757.3
# epoch  291 Training PSNR 20.141, estimated fx 1012.6 fy 756.0
# epoch  292 Training PSNR 20.017, estimated fx 1006.1 fy 755.8
# epoch  293 Training PSNR 20.083, estimated fx 1012.8 fy 754.1
# epoch  294 Training PSNR 20.071, estimated fx 1001.9 fy 756.9
# epoch  295 Training PSNR 20.106, estimated fx 1018.3 fy 749.8
# epoch  296 Training PSNR 19.767, estimated fx 1003.4 fy 761.2
# epoch  297 Training PSNR 19.918, estimated fx 1013.2 fy 747.3
# epoch  298 Training PSNR 19.909, estimated fx 1002.5 fy 757.5
# epoch  299 Training PSNR 20.390, estimated fx 1005.7 fy 749.5
# epoch  300 Training PSNR 20.133, estimated fx 1003.6 fy 753.0
# epoch  301 Training PSNR 20.247, estimated fx 1006.5 fy 749.6
# epoch  302 Training PSNR 20.269, estimated fx 1003.5 fy 756.1
# epoch  303 Training PSNR 20.486, estimated fx 1003.4 fy 752.8
# epoch  304 Training PSNR 20.345, estimated fx 1002.8 fy 760.4
# epoch  305 Training PSNR 20.366, estimated fx 1003.2 fy 748.2
# epoch  306 Training PSNR 20.243, estimated fx 997.0 fy 759.5
# epoch  307 Training PSNR 20.309, estimated fx 1005.0 fy 751.9
# epoch  308 Training PSNR 20.168, estimated fx 992.0 fy 757.1
# epoch  309 Training PSNR 20.155, estimated fx 1005.5 fy 751.4
# epoch  310 Training PSNR 20.231, estimated fx 995.1 fy 760.1
# epoch  311 Training PSNR 20.036, estimated fx 1007.0 fy 754.6
# epoch  312 Training PSNR 20.192, estimated fx 994.2 fy 760.8
# epoch  313 Training PSNR 20.028, estimated fx 1003.3 fy 750.7
# epoch  314 Training PSNR 20.185, estimated fx 995.7 fy 755.3
# epoch  315 Training PSNR 20.209, estimated fx 999.0 fy 755.2
# epoch  316 Training PSNR 20.275, estimated fx 995.1 fy 757.0
# epoch  317 Training PSNR 20.119, estimated fx 998.6 fy 752.3
# epoch  318 Training PSNR 19.964, estimated fx 991.3 fy 758.6
# epoch  319 Training PSNR 20.001, estimated fx 997.0 fy 751.1
# epoch  320 Training PSNR 20.146, estimated fx 988.1 fy 758.0
# epoch  321 Training PSNR 20.310, estimated fx 1000.8 fy 751.4
# epoch  322 Training PSNR 20.231, estimated fx 989.3 fy 757.6
# epoch  323 Training PSNR 20.375, estimated fx 996.0 fy 751.7
# epoch  324 Training PSNR 20.254, estimated fx 990.4 fy 758.3
# epoch  325 Training PSNR 20.297, estimated fx 995.3 fy 751.0
# epoch  326 Training PSNR 20.149, estimated fx 992.8 fy 756.7
# epoch  327 Training PSNR 20.172, estimated fx 993.9 fy 751.6
# epoch  328 Training PSNR 20.192, estimated fx 994.5 fy 755.8
# epoch  329 Training PSNR 20.303, estimated fx 987.4 fy 755.2
# epoch  330 Training PSNR 20.372, estimated fx 992.9 fy 753.1
# epoch  331 Training PSNR 20.282, estimated fx 990.0 fy 756.9
# epoch  332 Training PSNR 20.232, estimated fx 991.9 fy 751.9
# epoch  333 Training PSNR 20.223, estimated fx 991.6 fy 753.1
# epoch  334 Training PSNR 20.351, estimated fx 988.7 fy 752.2
# epoch  335 Training PSNR 20.273, estimated fx 991.0 fy 755.1
# epoch  336 Training PSNR 19.885, estimated fx 986.2 fy 754.8
# epoch  337 Training PSNR 20.246, estimated fx 993.7 fy 751.6
# epoch  338 Training PSNR 20.301, estimated fx 989.7 fy 755.9
# epoch  339 Training PSNR 20.277, estimated fx 988.9 fy 750.2
# epoch  340 Training PSNR 20.252, estimated fx 986.1 fy 755.6
# epoch  341 Training PSNR 20.234, estimated fx 989.4 fy 747.2
# epoch  342 Training PSNR 20.384, estimated fx 989.2 fy 756.2
# epoch  343 Training PSNR 20.474, estimated fx 984.8 fy 745.9
# epoch  344 Training PSNR 20.382, estimated fx 987.2 fy 756.9
# epoch  345 Training PSNR 20.189, estimated fx 989.5 fy 746.2
# epoch  346 Training PSNR 19.821, estimated fx 981.0 fy 755.7
# epoch  347 Training PSNR 20.169, estimated fx 988.1 fy 746.7
# epoch  348 Training PSNR 20.230, estimated fx 981.5 fy 755.5
# epoch  349 Training PSNR 19.966, estimated fx 985.6 fy 746.6
# epoch  350 Training PSNR 20.183, estimated fx 978.1 fy 754.3
# epoch  351 Training PSNR 20.389, estimated fx 985.5 fy 748.3
# epoch  352 Training PSNR 20.058, estimated fx 980.2 fy 754.5
# epoch  353 Training PSNR 20.472, estimated fx 984.5 fy 743.9
# epoch  354 Training PSNR 20.343, estimated fx 976.0 fy 753.9
# epoch  355 Training PSNR 20.284, estimated fx 988.0 fy 745.0
# epoch  356 Training PSNR 20.120, estimated fx 982.2 fy 753.5
# epoch  357 Training PSNR 20.357, estimated fx 976.1 fy 748.4
# epoch  358 Training PSNR 20.411, estimated fx 978.9 fy 750.4
# epoch  359 Training PSNR 20.086, estimated fx 980.9 fy 744.2
# epoch  360 Training PSNR 20.183, estimated fx 978.2 fy 753.1
# epoch  361 Training PSNR 20.221, estimated fx 978.2 fy 745.5
# epoch  362 Training PSNR 20.112, estimated fx 977.0 fy 749.4
# epoch  363 Training PSNR 20.411, estimated fx 975.6 fy 750.8
# epoch  364 Training PSNR 20.444, estimated fx 980.4 fy 747.4
# epoch  365 Training PSNR 20.424, estimated fx 974.8 fy 746.9
# epoch  366 Training PSNR 20.561, estimated fx 980.5 fy 750.5
# epoch  367 Training PSNR 20.309, estimated fx 974.3 fy 747.9
# epoch  368 Training PSNR 20.148, estimated fx 976.2 fy 752.5
# epoch  369 Training PSNR 20.215, estimated fx 974.3 fy 749.7
# epoch  370 Training PSNR 20.420, estimated fx 974.9 fy 750.4
# epoch  371 Training PSNR 20.480, estimated fx 974.0 fy 749.8
# epoch  372 Training PSNR 20.531, estimated fx 973.8 fy 750.0
# epoch  373 Training PSNR 20.227, estimated fx 975.7 fy 747.0
# epoch  374 Training PSNR 20.381, estimated fx 976.4 fy 750.2
# epoch  375 Training PSNR 20.241, estimated fx 969.6 fy 750.7
# epoch  376 Training PSNR 20.493, estimated fx 973.1 fy 750.1
# epoch  377 Training PSNR 20.322, estimated fx 974.5 fy 748.1
# epoch  378 Training PSNR 20.101, estimated fx 971.9 fy 752.0
# epoch  379 Training PSNR 20.335, estimated fx 974.1 fy 748.1
# epoch  380 Training PSNR 20.454, estimated fx 969.9 fy 750.4
# epoch  381 Training PSNR 20.351, estimated fx 970.2 fy 745.6
# epoch  382 Training PSNR 20.028, estimated fx 971.5 fy 745.8
# epoch  383 Training PSNR 20.427, estimated fx 967.6 fy 750.2
# epoch  384 Training PSNR 20.407, estimated fx 971.2 fy 744.6
# epoch  385 Training PSNR 20.320, estimated fx 965.5 fy 751.7
# epoch  386 Training PSNR 20.541, estimated fx 973.8 fy 744.1
# epoch  387 Training PSNR 20.196, estimated fx 965.4 fy 750.2
# epoch  388 Training PSNR 20.113, estimated fx 971.1 fy 741.4
# epoch  389 Training PSNR 20.243, estimated fx 965.6 fy 749.1
# epoch  390 Training PSNR 20.218, estimated fx 969.1 fy 744.0
# epoch  391 Training PSNR 20.390, estimated fx 965.7 fy 749.2
# epoch  392 Training PSNR 20.618, estimated fx 966.9 fy 745.1
# epoch  393 Training PSNR 20.769, estimated fx 966.7 fy 749.0
# epoch  394 Training PSNR 20.747, estimated fx 964.5 fy 747.6
# epoch  395 Training PSNR 20.563, estimated fx 966.2 fy 748.0
# epoch  396 Training PSNR 20.080, estimated fx 966.0 fy 745.9
# epoch  397 Training PSNR 20.285, estimated fx 963.9 fy 746.5
# epoch  398 Training PSNR 20.555, estimated fx 968.0 fy 747.4
# epoch  399 Training PSNR 20.254, estimated fx 957.3 fy 748.7
# epoch  400 Training PSNR 20.458, estimated fx 967.5 fy 744.3
# epoch  401 Training PSNR 20.430, estimated fx 961.1 fy 748.7
# epoch  402 Training PSNR 20.417, estimated fx 968.7 fy 741.2
# epoch  403 Training PSNR 20.686, estimated fx 959.6 fy 751.5
# epoch  404 Training PSNR 20.722, estimated fx 964.9 fy 745.5
# epoch  405 Training PSNR 20.860, estimated fx 959.1 fy 749.1
# epoch  406 Training PSNR 20.758, estimated fx 963.8 fy 744.0
# epoch  407 Training PSNR 20.671, estimated fx 957.7 fy 749.1
# epoch  408 Training PSNR 20.680, estimated fx 966.2 fy 744.3
# epoch  409 Training PSNR 20.645, estimated fx 956.7 fy 754.7
# epoch  410 Training PSNR 20.273, estimated fx 969.6 fy 740.6
# epoch  411 Training PSNR 20.453, estimated fx 956.1 fy 751.6
# epoch  412 Training PSNR 20.487, estimated fx 966.1 fy 741.8
# epoch  413 Training PSNR 20.432, estimated fx 958.9 fy 749.7
# epoch  414 Training PSNR 20.695, estimated fx 963.4 fy 742.0
# epoch  415 Training PSNR 20.634, estimated fx 956.8 fy 747.6
# epoch  416 Training PSNR 20.550, estimated fx 964.4 fy 742.9
# epoch  417 Training PSNR 20.542, estimated fx 956.9 fy 748.7
# epoch  418 Training PSNR 20.717, estimated fx 960.8 fy 743.2
# epoch  419 Training PSNR 20.696, estimated fx 958.0 fy 747.9
# epoch  420 Training PSNR 20.625, estimated fx 957.2 fy 744.9
# epoch  421 Training PSNR 20.750, estimated fx 958.8 fy 745.1
# epoch  422 Training PSNR 20.928, estimated fx 961.4 fy 745.2
# epoch  423 Training PSNR 20.741, estimated fx 957.7 fy 748.6
# epoch  424 Training PSNR 20.813, estimated fx 962.5 fy 745.2
# epoch  425 Training PSNR 20.665, estimated fx 955.7 fy 748.6
# epoch  426 Training PSNR 20.457, estimated fx 960.7 fy 745.5
# epoch  427 Training PSNR 20.610, estimated fx 954.0 fy 746.3
# epoch  428 Training PSNR 20.619, estimated fx 962.4 fy 741.8
# epoch  429 Training PSNR 20.439, estimated fx 951.6 fy 749.2
# epoch  430 Training PSNR 20.547, estimated fx 959.6 fy 745.4
# epoch  431 Training PSNR 20.772, estimated fx 955.5 fy 748.0
# epoch  432 Training PSNR 20.770, estimated fx 961.7 fy 743.1
# epoch  433 Training PSNR 20.691, estimated fx 956.2 fy 749.2
# epoch  434 Training PSNR 20.831, estimated fx 959.0 fy 744.4
# epoch  435 Training PSNR 20.778, estimated fx 954.0 fy 748.5
# epoch  436 Training PSNR 20.807, estimated fx 957.9 fy 744.0
# epoch  437 Training PSNR 20.764, estimated fx 950.2 fy 752.5
# epoch  438 Training PSNR 20.655, estimated fx 960.2 fy 741.9
# epoch  439 Training PSNR 20.556, estimated fx 950.0 fy 751.1
# epoch  440 Training PSNR 20.543, estimated fx 958.0 fy 742.1
# epoch  441 Training PSNR 20.813, estimated fx 954.9 fy 747.2
# epoch  442 Training PSNR 20.884, estimated fx 954.5 fy 745.8
# epoch  443 Training PSNR 20.878, estimated fx 951.5 fy 743.1
# epoch  444 Training PSNR 20.679, estimated fx 956.4 fy 749.5
# epoch  445 Training PSNR 20.692, estimated fx 954.5 fy 744.7
# epoch  446 Training PSNR 20.634, estimated fx 955.0 fy 747.9
# epoch  447 Training PSNR 20.598, estimated fx 954.3 fy 742.9
# epoch  448 Training PSNR 20.496, estimated fx 952.8 fy 744.5
# epoch  449 Training PSNR 20.643, estimated fx 952.1 fy 744.7
# epoch  450 Training PSNR 20.709, estimated fx 952.2 fy 746.7
# epoch  451 Training PSNR 20.517, estimated fx 949.5 fy 744.5
# epoch  452 Training PSNR 20.899, estimated fx 954.7 fy 743.3
# epoch  453 Training PSNR 20.721, estimated fx 948.7 fy 748.3
# epoch  454 Training PSNR 20.822, estimated fx 953.5 fy 742.9
# epoch  455 Training PSNR 20.678, estimated fx 946.4 fy 746.9
# epoch  456 Training PSNR 20.491, estimated fx 953.8 fy 744.2
# epoch  457 Training PSNR 20.646, estimated fx 950.2 fy 747.3
# epoch  458 Training PSNR 20.785, estimated fx 950.7 fy 746.3
# epoch  459 Training PSNR 20.704, estimated fx 948.1 fy 745.8
# epoch  460 Training PSNR 20.467, estimated fx 949.7 fy 743.3
# epoch  461 Training PSNR 20.517, estimated fx 947.8 fy 745.3
# epoch  462 Training PSNR 20.621, estimated fx 951.2 fy 745.3
# epoch  463 Training PSNR 20.730, estimated fx 949.2 fy 744.6
# epoch  464 Training PSNR 20.762, estimated fx 950.1 fy 745.4
# epoch  465 Training PSNR 20.628, estimated fx 943.8 fy 746.5
# epoch  466 Training PSNR 20.588, estimated fx 949.2 fy 744.2
# epoch  467 Training PSNR 20.609, estimated fx 945.1 fy 745.5
# epoch  468 Training PSNR 20.602, estimated fx 951.6 fy 744.0
# epoch  469 Training PSNR 20.669, estimated fx 944.5 fy 747.2
# epoch  470 Training PSNR 20.621, estimated fx 951.0 fy 740.0
# epoch  471 Training PSNR 20.463, estimated fx 944.7 fy 745.9
# epoch  472 Training PSNR 20.941, estimated fx 947.9 fy 743.9
# epoch  473 Training PSNR 20.764, estimated fx 944.9 fy 743.4
# epoch  474 Training PSNR 20.848, estimated fx 947.9 fy 745.5
# epoch  475 Training PSNR 20.790, estimated fx 941.7 fy 745.2
# epoch  476 Training PSNR 20.616, estimated fx 949.5 fy 744.3
# epoch  477 Training PSNR 20.817, estimated fx 943.8 fy 741.6
# epoch  478 Training PSNR 20.932, estimated fx 948.9 fy 745.2
# epoch  479 Training PSNR 20.665, estimated fx 944.1 fy 743.6
# epoch  480 Training PSNR 20.528, estimated fx 948.6 fy 744.8
# epoch  481 Training PSNR 20.595, estimated fx 944.2 fy 744.2
# epoch  482 Training PSNR 20.847, estimated fx 943.3 fy 746.4
# epoch  483 Training PSNR 21.164, estimated fx 945.8 fy 743.2
# epoch  484 Training PSNR 21.052, estimated fx 944.2 fy 743.8
# epoch  485 Training PSNR 21.020, estimated fx 944.4 fy 743.8
# epoch  486 Training PSNR 20.672, estimated fx 943.6 fy 742.7
# epoch  487 Training PSNR 20.865, estimated fx 942.6 fy 746.6
# epoch  488 Training PSNR 20.822, estimated fx 943.5 fy 743.7
# epoch  489 Training PSNR 20.728, estimated fx 944.7 fy 745.9
# epoch  490 Training PSNR 20.955, estimated fx 939.1 fy 748.0
# epoch  491 Training PSNR 20.893, estimated fx 943.3 fy 745.0
# epoch  492 Training PSNR 20.724, estimated fx 941.6 fy 745.6
# epoch  493 Training PSNR 20.836, estimated fx 943.0 fy 745.4
# epoch  494 Training PSNR 20.801, estimated fx 938.6 fy 746.7
# epoch  495 Training PSNR 20.618, estimated fx 946.8 fy 742.1
# epoch  496 Training PSNR 20.577, estimated fx 937.0 fy 748.0
# epoch  497 Training PSNR 20.688, estimated fx 944.3 fy 742.0
# epoch  498 Training PSNR 20.792, estimated fx 937.8 fy 747.9
# epoch  499 Training PSNR 20.776, estimated fx 941.2 fy 743.4
# epoch  500 Training PSNR 20.837, estimated fx 941.3 fy 746.0
# epoch  501 Training PSNR 20.939, estimated fx 940.7 fy 743.3
# epoch  502 Training PSNR 20.911, estimated fx 943.0 fy 743.7
# epoch  503 Training PSNR 21.106, estimated fx 939.4 fy 744.7
# epoch  504 Training PSNR 21.113, estimated fx 943.3 fy 743.9
# epoch  505 Training PSNR 21.120, estimated fx 938.9 fy 745.6
# epoch  506 Training PSNR 21.100, estimated fx 940.6 fy 743.8
# epoch  507 Training PSNR 20.855, estimated fx 936.6 fy 744.7
# epoch  508 Training PSNR 20.927, estimated fx 942.1 fy 745.4
# epoch  509 Training PSNR 21.015, estimated fx 935.7 fy 747.2
# epoch  510 Training PSNR 20.911, estimated fx 939.9 fy 745.1
# epoch  511 Training PSNR 20.990, estimated fx 938.1 fy 746.9
# epoch  512 Training PSNR 20.959, estimated fx 938.5 fy 744.1
# epoch  513 Training PSNR 20.981, estimated fx 941.8 fy 746.9
# epoch  514 Training PSNR 20.949, estimated fx 934.3 fy 747.1
# epoch  515 Training PSNR 21.017, estimated fx 940.4 fy 746.2
# epoch  516 Training PSNR 20.924, estimated fx 937.1 fy 744.5
# epoch  517 Training PSNR 21.078, estimated fx 940.6 fy 745.4
# epoch  518 Training PSNR 21.067, estimated fx 936.9 fy 746.5
# epoch  519 Training PSNR 20.911, estimated fx 938.5 fy 744.7
# epoch  520 Training PSNR 21.058, estimated fx 938.1 fy 748.1
# epoch  521 Training PSNR 20.921, estimated fx 936.8 fy 743.8
# epoch  522 Training PSNR 21.144, estimated fx 934.8 fy 748.9
# epoch  523 Training PSNR 21.027, estimated fx 936.2 fy 746.2
# epoch  524 Training PSNR 20.870, estimated fx 937.2 fy 748.2
# epoch  525 Training PSNR 20.949, estimated fx 936.9 fy 746.5
# epoch  526 Training PSNR 20.841, estimated fx 935.4 fy 749.0
# epoch  527 Training PSNR 21.038, estimated fx 939.2 fy 746.7
# epoch  528 Training PSNR 20.881, estimated fx 936.0 fy 749.5
# epoch  529 Training PSNR 20.892, estimated fx 938.1 fy 744.0
# epoch  530 Training PSNR 20.907, estimated fx 933.7 fy 747.5
# epoch  531 Training PSNR 21.211, estimated fx 938.9 fy 742.7
# epoch  532 Training PSNR 20.810, estimated fx 932.0 fy 750.2
# epoch  533 Training PSNR 20.688, estimated fx 938.0 fy 743.2
# epoch  534 Training PSNR 20.911, estimated fx 934.1 fy 749.2
# epoch  535 Training PSNR 20.940, estimated fx 938.1 fy 743.9
# epoch  536 Training PSNR 21.075, estimated fx 933.2 fy 747.9
# epoch  537 Training PSNR 20.976, estimated fx 937.7 fy 744.9
# epoch  538 Training PSNR 20.938, estimated fx 933.2 fy 749.0
# epoch  539 Training PSNR 20.924, estimated fx 938.3 fy 743.5
# epoch  540 Training PSNR 20.818, estimated fx 931.2 fy 746.2
# epoch  541 Training PSNR 20.964, estimated fx 939.0 fy 744.7
# epoch  542 Training PSNR 21.254, estimated fx 930.1 fy 745.5
# epoch  543 Training PSNR 21.210, estimated fx 937.5 fy 743.2
# epoch  544 Training PSNR 21.158, estimated fx 926.5 fy 748.0
# epoch  545 Training PSNR 21.132, estimated fx 935.2 fy 744.3
# epoch  546 Training PSNR 20.773, estimated fx 931.2 fy 747.8
# epoch  547 Training PSNR 21.126, estimated fx 935.0 fy 743.4
# epoch  548 Training PSNR 21.162, estimated fx 932.0 fy 746.5
# epoch  549 Training PSNR 21.158, estimated fx 934.8 fy 743.5
# epoch  550 Training PSNR 21.120, estimated fx 930.2 fy 749.7
# epoch  551 Training PSNR 21.183, estimated fx 934.6 fy 744.7
# epoch  552 Training PSNR 21.304, estimated fx 932.7 fy 745.7
# epoch  553 Training PSNR 21.203, estimated fx 934.6 fy 740.7
# epoch  554 Training PSNR 21.190, estimated fx 931.2 fy 748.9
# epoch  555 Training PSNR 21.126, estimated fx 932.7 fy 745.0
# epoch  556 Training PSNR 21.075, estimated fx 932.9 fy 747.3
# epoch  557 Training PSNR 20.961, estimated fx 932.3 fy 745.6
# epoch  558 Training PSNR 21.332, estimated fx 930.1 fy 747.6
# epoch  559 Training PSNR 20.926, estimated fx 933.8 fy 744.5
# epoch  560 Training PSNR 20.856, estimated fx 930.9 fy 748.9
# epoch  561 Training PSNR 21.051, estimated fx 932.7 fy 746.1
# epoch  562 Training PSNR 20.985, estimated fx 928.7 fy 746.5
# epoch  563 Training PSNR 21.077, estimated fx 932.5 fy 744.6
# epoch  564 Training PSNR 21.104, estimated fx 932.2 fy 748.1
# epoch  565 Training PSNR 21.021, estimated fx 931.7 fy 743.9
# epoch  566 Training PSNR 21.172, estimated fx 929.3 fy 748.2
# epoch  567 Training PSNR 21.158, estimated fx 928.9 fy 745.2
# epoch  568 Training PSNR 20.855, estimated fx 931.3 fy 744.7
# epoch  569 Training PSNR 21.097, estimated fx 931.9 fy 746.5
# epoch  571 Training PSNR 20.908, estimated fx 927.4 fy 748.4
# epoch  572 Training PSNR 20.766, estimated fx 932.7 fy 744.4
# epoch  573 Training PSNR 20.472, estimated fx 926.2 fy 746.3
# epoch  574 Training PSNR 20.975, estimated fx 931.8 fy 745.8
# epoch  575 Training PSNR 21.111, estimated fx 925.5 fy 749.0
# epoch  576 Training PSNR 21.129, estimated fx 930.9 fy 745.0
# epoch  577 Training PSNR 21.226, estimated fx 925.6 fy 747.9
# epoch  578 Training PSNR 21.022, estimated fx 931.7 fy 743.2
# epoch  579 Training PSNR 21.012, estimated fx 926.8 fy 747.5
# epoch  580 Training PSNR 21.021, estimated fx 931.1 fy 745.5
# epoch  581 Training PSNR 21.209, estimated fx 928.0 fy 747.1
# epoch  582 Training PSNR 21.289, estimated fx 932.3 fy 741.9
# epoch  583 Training PSNR 21.036, estimated fx 925.4 fy 750.0
# epoch  584 Training PSNR 21.092, estimated fx 930.0 fy 742.0
# epoch  585 Training PSNR 20.917, estimated fx 928.4 fy 746.7
# epoch  586 Training PSNR 21.048, estimated fx 929.2 fy 743.6
# epoch  587 Training PSNR 21.144, estimated fx 924.6 fy 749.1
# epoch  588 Training PSNR 21.055, estimated fx 930.2 fy 742.6
# epoch  589 Training PSNR 21.146, estimated fx 923.1 fy 749.7
# epoch  590 Training PSNR 21.058, estimated fx 930.1 fy 744.8
# epoch  591 Training PSNR 21.086, estimated fx 924.8 fy 747.3
# epoch  592 Training PSNR 20.890, estimated fx 930.6 fy 741.5
# epoch  593 Training PSNR 20.827, estimated fx 922.9 fy 749.0
# epoch  594 Training PSNR 21.187, estimated fx 930.3 fy 743.5
# epoch  595 Training PSNR 21.079, estimated fx 922.6 fy 749.6
# epoch  596 Training PSNR 20.911, estimated fx 931.7 fy 742.7
# epoch  597 Training PSNR 21.000, estimated fx 926.0 fy 750.0
# epoch  598 Training PSNR 21.134, estimated fx 927.6 fy 739.7
# epoch  599 Training PSNR 20.778, estimated fx 923.1 fy 749.3
# epoch  600 Training PSNR 21.265, estimated fx 926.9 fy 744.6
# epoch  601 Training PSNR 21.459, estimated fx 923.2 fy 748.0
# epoch  602 Training PSNR 21.381, estimated fx 928.8 fy 742.6
# epoch  603 Training PSNR 21.244, estimated fx 923.5 fy 748.2
# epoch  604 Training PSNR 21.434, estimated fx 929.2 fy 743.6
# epoch  605 Training PSNR 21.552, estimated fx 923.4 fy 747.5
# epoch  606 Training PSNR 21.419, estimated fx 925.3 fy 741.0
# epoch  607 Training PSNR 21.042, estimated fx 922.5 fy 748.2
# epoch  608 Training PSNR 21.075, estimated fx 927.0 fy 743.2
# epoch  609 Training PSNR 21.353, estimated fx 924.3 fy 750.0
# epoch  610 Training PSNR 21.330, estimated fx 926.7 fy 743.4
# epoch  611 Training PSNR 20.952, estimated fx 923.5 fy 750.5
# epoch  612 Training PSNR 21.077, estimated fx 926.2 fy 744.8
# epoch  613 Training PSNR 21.362, estimated fx 926.9 fy 748.7
# epoch  614 Training PSNR 21.413, estimated fx 924.4 fy 745.2
# epoch  615 Training PSNR 21.699, estimated fx 927.0 fy 746.6
# epoch  616 Training PSNR 21.399, estimated fx 923.0 fy 747.3
# epoch  617 Training PSNR 21.389, estimated fx 929.1 fy 745.6
# epoch  618 Training PSNR 21.299, estimated fx 923.7 fy 748.3
# epoch  619 Training PSNR 21.436, estimated fx 927.1 fy 745.4
# epoch  620 Training PSNR 21.556, estimated fx 924.9 fy 748.8
# epoch  621 Training PSNR 21.205, estimated fx 923.6 fy 744.7
# epoch  622 Training PSNR 21.387, estimated fx 926.9 fy 747.2
# epoch  623 Training PSNR 21.258, estimated fx 924.7 fy 747.9
# epoch  624 Training PSNR 20.979, estimated fx 924.5 fy 748.0
# epoch  625 Training PSNR 21.034, estimated fx 923.9 fy 745.8
# epoch  626 Training PSNR 21.079, estimated fx 924.8 fy 749.4
# epoch  627 Training PSNR 21.431, estimated fx 923.1 fy 750.5
# epoch  628 Training PSNR 21.634, estimated fx 927.4 fy 746.3
# epoch  629 Training PSNR 21.526, estimated fx 922.5 fy 752.8
# epoch  630 Training PSNR 21.279, estimated fx 925.1 fy 746.2
# epoch  631 Training PSNR 21.338, estimated fx 921.6 fy 751.2
# epoch  632 Training PSNR 21.529, estimated fx 926.1 fy 749.5
# epoch  633 Training PSNR 21.422, estimated fx 921.8 fy 750.4
# epoch  634 Training PSNR 21.387, estimated fx 924.9 fy 747.7
# epoch  635 Training PSNR 21.139, estimated fx 923.3 fy 748.1
# epoch  636 Training PSNR 21.167, estimated fx 926.8 fy 746.9
# epoch  637 Training PSNR 21.395, estimated fx 919.3 fy 751.2
# epoch  638 Training PSNR 20.962, estimated fx 927.2 fy 745.8
# epoch  639 Training PSNR 21.464, estimated fx 919.3 fy 751.6
# epoch  640 Training PSNR 21.214, estimated fx 929.4 fy 745.2
# epoch  641 Training PSNR 20.996, estimated fx 915.7 fy 750.0
# epoch  642 Training PSNR 21.082, estimated fx 926.0 fy 744.1
# epoch  643 Training PSNR 21.355, estimated fx 917.4 fy 750.6
# epoch  644 Training PSNR 21.180, estimated fx 924.6 fy 747.2
# epoch  645 Training PSNR 21.201, estimated fx 919.4 fy 751.3
# epoch  646 Training PSNR 21.390, estimated fx 927.3 fy 747.0
# epoch  647 Training PSNR 21.247, estimated fx 919.2 fy 750.3
# epoch  648 Training PSNR 21.255, estimated fx 924.8 fy 744.9
# epoch  649 Training PSNR 21.427, estimated fx 922.0 fy 748.7
# epoch  650 Training PSNR 21.467, estimated fx 923.2 fy 747.0
# epoch  651 Training PSNR 21.457, estimated fx 921.5 fy 750.3
# epoch  652 Training PSNR 21.543, estimated fx 924.2 fy 747.2
# epoch  653 Training PSNR 21.420, estimated fx 923.1 fy 749.6
# epoch  654 Training PSNR 21.560, estimated fx 920.4 fy 748.6
# epoch  655 Training PSNR 21.373, estimated fx 922.9 fy 749.7
# epoch  656 Training PSNR 21.454, estimated fx 920.1 fy 747.8
# epoch  657 Training PSNR 21.195, estimated fx 925.5 fy 747.7
# epoch  658 Training PSNR 21.310, estimated fx 918.2 fy 749.9
# epoch  659 Training PSNR 21.316, estimated fx 922.7 fy 748.8
# epoch  660 Training PSNR 21.514, estimated fx 918.4 fy 749.5
# epoch  661 Training PSNR 21.353, estimated fx 923.9 fy 750.1
# epoch  662 Training PSNR 21.358, estimated fx 920.0 fy 747.0
# epoch  663 Training PSNR 20.971, estimated fx 920.2 fy 749.0
# epoch  664 Training PSNR 21.139, estimated fx 916.7 fy 750.9
# epoch  665 Training PSNR 21.119, estimated fx 922.4 fy 745.9
# epoch  666 Training PSNR 21.395, estimated fx 921.5 fy 749.2
# epoch  667 Training PSNR 21.476, estimated fx 923.5 fy 745.6
# epoch  668 Training PSNR 21.312, estimated fx 917.9 fy 751.0
# epoch  669 Training PSNR 21.323, estimated fx 924.8 fy 746.0
# epoch  670 Training PSNR 21.468, estimated fx 916.2 fy 751.8
# epoch  671 Training PSNR 21.517, estimated fx 922.6 fy 746.0
# epoch  672 Training PSNR 21.269, estimated fx 918.1 fy 750.8
# epoch  673 Training PSNR 21.463, estimated fx 922.3 fy 749.1
# epoch  674 Training PSNR 21.342, estimated fx 916.5 fy 750.9
# epoch  675 Training PSNR 21.120, estimated fx 923.3 fy 748.6
# epoch  676 Training PSNR 20.984, estimated fx 917.5 fy 749.6
# epoch  677 Training PSNR 21.176, estimated fx 922.6 fy 747.4
# epoch  678 Training PSNR 21.309, estimated fx 917.6 fy 752.5
# epoch  679 Training PSNR 21.348, estimated fx 921.8 fy 747.3
# epoch  680 Training PSNR 21.472, estimated fx 918.7 fy 750.5
# epoch  681 Training PSNR 21.640, estimated fx 920.3 fy 749.8
# epoch  682 Training PSNR 21.398, estimated fx 919.6 fy 749.9
# epoch  683 Training PSNR 21.498, estimated fx 920.3 fy 748.9
# epoch  684 Training PSNR 21.512, estimated fx 917.3 fy 750.0
# epoch  685 Training PSNR 21.240, estimated fx 919.8 fy 749.1
# epoch  686 Training PSNR 21.351, estimated fx 917.8 fy 749.7
# epoch  687 Training PSNR 21.334, estimated fx 921.7 fy 746.7
# epoch  688 Training PSNR 21.464, estimated fx 916.6 fy 750.9
# epoch  689 Training PSNR 21.449, estimated fx 921.8 fy 748.2
# epoch  690 Training PSNR 21.292, estimated fx 915.7 fy 752.2
# epoch  691 Training PSNR 21.324, estimated fx 919.2 fy 747.6
# epoch  692 Training PSNR 21.389, estimated fx 916.4 fy 752.3
# epoch  693 Training PSNR 21.451, estimated fx 921.1 fy 746.6
# epoch  694 Training PSNR 21.448, estimated fx 915.0 fy 751.6
# epoch  695 Training PSNR 21.246, estimated fx 919.4 fy 748.2
# epoch  696 Training PSNR 21.325, estimated fx 916.7 fy 750.8
# epoch  697 Training PSNR 21.464, estimated fx 917.6 fy 749.7
# epoch  698 Training PSNR 21.583, estimated fx 919.7 fy 747.5
# epoch  699 Training PSNR 21.521, estimated fx 915.3 fy 748.1
# epoch  700 Training PSNR 21.795, estimated fx 919.1 fy 749.9
# epoch  701 Training PSNR 21.791, estimated fx 916.4 fy 749.0
# epoch  702 Training PSNR 21.712, estimated fx 919.1 fy 749.0
# epoch  703 Training PSNR 21.628, estimated fx 918.2 fy 750.2
# epoch  704 Training PSNR 21.767, estimated fx 916.8 fy 749.2
# epoch  705 Training PSNR 21.826, estimated fx 919.4 fy 750.0
# epoch  706 Training PSNR 21.875, estimated fx 915.3 fy 752.6
# epoch  707 Training PSNR 21.662, estimated fx 920.0 fy 749.9
# epoch  708 Training PSNR 21.872, estimated fx 917.8 fy 753.3
# epoch  709 Training PSNR 21.763, estimated fx 918.1 fy 750.7
# epoch  710 Training PSNR 21.735, estimated fx 918.3 fy 753.0
# epoch  711 Training PSNR 21.805, estimated fx 918.1 fy 750.7
# epoch  712 Training PSNR 21.606, estimated fx 916.2 fy 752.4
# epoch  713 Training PSNR 21.604, estimated fx 919.6 fy 749.0
# epoch  714 Training PSNR 21.480, estimated fx 916.0 fy 752.9
# epoch  715 Training PSNR 21.297, estimated fx 915.7 fy 751.1
# epoch  716 Training PSNR 21.416, estimated fx 916.2 fy 754.5
# epoch  717 Training PSNR 21.483, estimated fx 916.0 fy 749.9
# epoch  718 Training PSNR 21.556, estimated fx 919.3 fy 754.3
# epoch  719 Training PSNR 21.349, estimated fx 918.0 fy 750.8
# epoch  720 Training PSNR 21.536, estimated fx 913.9 fy 755.1
# epoch  721 Training PSNR 21.332, estimated fx 918.7 fy 748.1
# epoch  722 Training PSNR 21.425, estimated fx 914.5 fy 752.2
# epoch  723 Training PSNR 21.420, estimated fx 918.4 fy 750.1
# epoch  724 Training PSNR 21.819, estimated fx 917.1 fy 752.6
# epoch  725 Training PSNR 21.793, estimated fx 916.3 fy 753.4
# epoch  726 Training PSNR 21.724, estimated fx 917.9 fy 751.1
# epoch  727 Training PSNR 21.707, estimated fx 917.2 fy 754.1
# epoch  728 Training PSNR 21.739, estimated fx 917.7 fy 750.8
# epoch  729 Training PSNR 21.706, estimated fx 915.7 fy 754.1
# epoch  730 Training PSNR 21.591, estimated fx 917.0 fy 751.8
# epoch  731 Training PSNR 21.701, estimated fx 916.6 fy 754.1
# epoch  732 Training PSNR 21.507, estimated fx 917.7 fy 753.2
# epoch  733 Training PSNR 21.715, estimated fx 916.2 fy 751.3
# epoch  734 Training PSNR 21.800, estimated fx 917.0 fy 753.8
# epoch  735 Training PSNR 21.741, estimated fx 917.4 fy 750.7
# epoch  736 Training PSNR 21.889, estimated fx 916.6 fy 752.7
# epoch  737 Training PSNR 21.790, estimated fx 916.9 fy 753.2
# epoch  738 Training PSNR 21.741, estimated fx 917.8 fy 753.6
# epoch  739 Training PSNR 21.546, estimated fx 918.2 fy 752.0
# epoch  740 Training PSNR 21.589, estimated fx 916.7 fy 752.9
# epoch  741 Training PSNR 21.639, estimated fx 918.1 fy 750.4
# epoch  742 Training PSNR 21.732, estimated fx 915.4 fy 751.7
# epoch  743 Training PSNR 21.570, estimated fx 918.6 fy 752.0
# epoch  744 Training PSNR 21.640, estimated fx 913.9 fy 752.8
# epoch  745 Training PSNR 21.570, estimated fx 918.7 fy 752.5
# epoch  746 Training PSNR 21.433, estimated fx 913.9 fy 752.5
# epoch  747 Training PSNR 21.542, estimated fx 920.3 fy 751.7
# epoch  748 Training PSNR 21.507, estimated fx 914.8 fy 753.4
# epoch  749 Training PSNR 21.614, estimated fx 918.8 fy 754.8
# epoch  750 Training PSNR 21.729, estimated fx 913.9 fy 753.6
# epoch  751 Training PSNR 21.523, estimated fx 922.1 fy 751.9
# epoch  752 Training PSNR 21.709, estimated fx 911.1 fy 753.8
# epoch  753 Training PSNR 21.264, estimated fx 916.5 fy 753.0
# epoch  754 Training PSNR 21.694, estimated fx 914.9 fy 754.6
# epoch  755 Training PSNR 21.791, estimated fx 917.8 fy 751.0
# epoch  756 Training PSNR 21.740, estimated fx 914.5 fy 757.3
# epoch  757 Training PSNR 21.682, estimated fx 916.6 fy 751.1
# epoch  758 Training PSNR 21.671, estimated fx 915.4 fy 757.0
# epoch  759 Training PSNR 21.610, estimated fx 917.3 fy 753.9
# epoch  760 Training PSNR 21.681, estimated fx 916.0 fy 753.7
# epoch  761 Training PSNR 21.532, estimated fx 915.5 fy 753.2
# epoch  762 Training PSNR 21.833, estimated fx 915.9 fy 754.1
# epoch  763 Training PSNR 21.527, estimated fx 913.4 fy 754.0
# epoch  764 Training PSNR 21.440, estimated fx 919.3 fy 753.2
# epoch  765 Training PSNR 21.215, estimated fx 913.2 fy 753.1
# epoch  766 Training PSNR 21.533, estimated fx 916.8 fy 752.8
# epoch  767 Training PSNR 21.592, estimated fx 914.6 fy 753.1
# epoch  768 Training PSNR 21.536, estimated fx 915.7 fy 752.3
# epoch  769 Training PSNR 21.588, estimated fx 916.0 fy 752.2
# epoch  770 Training PSNR 21.847, estimated fx 916.2 fy 752.8
# epoch  771 Training PSNR 21.648, estimated fx 913.2 fy 755.5
# epoch  772 Training PSNR 21.774, estimated fx 916.5 fy 752.3
# epoch  773 Training PSNR 21.464, estimated fx 914.1 fy 754.4
# epoch  774 Training PSNR 21.447, estimated fx 917.4 fy 750.9
# epoch  775 Training PSNR 21.172, estimated fx 912.6 fy 754.3
# epoch  776 Training PSNR 21.387, estimated fx 916.4 fy 750.7
# epoch  777 Training PSNR 21.792, estimated fx 913.7 fy 754.5
# epoch  778 Training PSNR 21.680, estimated fx 915.5 fy 750.3
# epoch  779 Training PSNR 21.608, estimated fx 913.3 fy 754.2
# epoch  780 Training PSNR 21.699, estimated fx 914.5 fy 751.5
# epoch  781 Training PSNR 21.825, estimated fx 916.8 fy 753.6
# epoch  782 Training PSNR 21.565, estimated fx 915.3 fy 752.5
# epoch  783 Training PSNR 21.743, estimated fx 915.1 fy 753.2
# epoch  784 Training PSNR 21.854, estimated fx 915.0 fy 753.2
# epoch  785 Training PSNR 21.831, estimated fx 914.5 fy 754.0
# epoch  786 Training PSNR 21.635, estimated fx 913.3 fy 756.0
# epoch  787 Training PSNR 21.685, estimated fx 915.4 fy 752.9
# epoch  788 Training PSNR 21.577, estimated fx 914.5 fy 754.0
# epoch  789 Training PSNR 21.477, estimated fx 914.5 fy 753.9
# epoch  790 Training PSNR 21.758, estimated fx 915.0 fy 752.8
# epoch  791 Training PSNR 21.698, estimated fx 913.1 fy 755.9
# epoch  792 Training PSNR 21.840, estimated fx 914.6 fy 752.8
# epoch  793 Training PSNR 21.586, estimated fx 912.7 fy 757.3
# epoch  794 Training PSNR 21.480, estimated fx 915.8 fy 751.2
# epoch  795 Training PSNR 21.601, estimated fx 912.8 fy 757.2
# epoch  796 Training PSNR 21.623, estimated fx 915.5 fy 751.4
# epoch  797 Training PSNR 21.771, estimated fx 913.5 fy 755.8
# epoch  798 Training PSNR 21.943, estimated fx 915.2 fy 753.2
# epoch  799 Training PSNR 21.785, estimated fx 908.9 fy 755.9
# epoch  800 Training PSNR 21.595, estimated fx 918.0 fy 753.6
# epoch  801 Training PSNR 21.643, estimated fx 910.6 fy 755.4
# epoch  802 Training PSNR 21.692, estimated fx 916.3 fy 753.8
# epoch  803 Training PSNR 21.893, estimated fx 910.8 fy 755.3
# epoch  804 Training PSNR 21.957, estimated fx 915.1 fy 754.3
# epoch  805 Training PSNR 21.963, estimated fx 912.4 fy 754.3
# epoch  806 Training PSNR 21.936, estimated fx 913.6 fy 755.3
# epoch  807 Training PSNR 21.954, estimated fx 914.8 fy 755.0
# epoch  808 Training PSNR 21.899, estimated fx 914.2 fy 756.4
# epoch  809 Training PSNR 21.914, estimated fx 913.9 fy 754.2
# epoch  810 Training PSNR 21.935, estimated fx 915.9 fy 756.1
# epoch  811 Training PSNR 21.865, estimated fx 914.7 fy 755.5
# epoch  812 Training PSNR 21.974, estimated fx 915.2 fy 756.0
# epoch  813 Training PSNR 21.964, estimated fx 912.2 fy 755.8
# epoch  814 Training PSNR 21.864, estimated fx 913.8 fy 756.1
# epoch  815 Training PSNR 22.011, estimated fx 914.3 fy 755.2
# epoch  816 Training PSNR 21.886, estimated fx 911.7 fy 757.2
# epoch  817 Training PSNR 21.854, estimated fx 916.4 fy 755.0
# epoch  818 Training PSNR 21.859, estimated fx 912.2 fy 756.8
# epoch  819 Training PSNR 22.059, estimated fx 915.5 fy 755.1
# epoch  820 Training PSNR 21.987, estimated fx 912.0 fy 758.0
# epoch  821 Training PSNR 22.097, estimated fx 915.2 fy 755.0
# epoch  822 Training PSNR 21.959, estimated fx 912.1 fy 758.6
# epoch  823 Training PSNR 21.749, estimated fx 915.5 fy 755.6
# epoch  824 Training PSNR 21.750, estimated fx 913.0 fy 758.2
# epoch  825 Training PSNR 22.028, estimated fx 916.0 fy 757.0
# epoch  826 Training PSNR 21.789, estimated fx 913.9 fy 758.6
# epoch  827 Training PSNR 21.584, estimated fx 913.9 fy 755.9
# epoch  828 Training PSNR 21.576, estimated fx 914.8 fy 757.0
# epoch  829 Training PSNR 21.878, estimated fx 914.1 fy 757.4
# epoch  830 Training PSNR 21.585, estimated fx 914.6 fy 757.2
# epoch  831 Training PSNR 21.811, estimated fx 914.2 fy 757.3
# epoch  832 Training PSNR 22.056, estimated fx 914.9 fy 758.9
# epoch  833 Training PSNR 21.996, estimated fx 913.5 fy 757.9
# epoch  834 Training PSNR 21.971, estimated fx 916.3 fy 758.8
# epoch  835 Training PSNR 21.969, estimated fx 915.1 fy 757.6
# epoch  836 Training PSNR 22.029, estimated fx 914.8 fy 759.2
# epoch  837 Training PSNR 21.936, estimated fx 917.3 fy 757.2
# epoch  838 Training PSNR 21.898, estimated fx 913.9 fy 758.7
# epoch  839 Training PSNR 21.976, estimated fx 916.5 fy 759.2
# epoch  840 Training PSNR 21.749, estimated fx 911.6 fy 758.2
# epoch  841 Training PSNR 21.504, estimated fx 918.5 fy 757.5
# epoch  842 Training PSNR 21.726, estimated fx 913.9 fy 759.2
# epoch  843 Training PSNR 21.992, estimated fx 915.4 fy 756.2
# epoch  844 Training PSNR 21.866, estimated fx 912.3 fy 760.5
# epoch  845 Training PSNR 21.696, estimated fx 916.0 fy 757.5
# epoch  846 Training PSNR 21.583, estimated fx 912.3 fy 758.0
# epoch  847 Training PSNR 21.794, estimated fx 916.4 fy 758.1
# epoch  848 Training PSNR 21.815, estimated fx 911.5 fy 757.9
# epoch  849 Training PSNR 21.761, estimated fx 914.8 fy 757.2
# epoch  850 Training PSNR 21.990, estimated fx 913.9 fy 758.5
# epoch  851 Training PSNR 21.920, estimated fx 914.4 fy 755.6
# epoch  852 Training PSNR 21.762, estimated fx 913.9 fy 759.5
# epoch  853 Training PSNR 21.802, estimated fx 915.2 fy 757.8
# epoch  854 Training PSNR 21.871, estimated fx 914.0 fy 759.5
# epoch  855 Training PSNR 21.841, estimated fx 912.8 fy 758.0
# epoch  856 Training PSNR 22.030, estimated fx 913.7 fy 759.3
# epoch  857 Training PSNR 21.691, estimated fx 912.7 fy 760.7
# epoch  858 Training PSNR 21.744, estimated fx 913.9 fy 756.9
# epoch  859 Training PSNR 22.116, estimated fx 912.3 fy 757.7
# epoch  860 Training PSNR 22.011, estimated fx 915.8 fy 758.6
# epoch  861 Training PSNR 22.010, estimated fx 914.0 fy 759.0
# epoch  862 Training PSNR 21.958, estimated fx 913.5 fy 758.7
# epoch  863 Training PSNR 21.783, estimated fx 913.2 fy 760.8
# epoch  864 Training PSNR 21.983, estimated fx 911.8 fy 760.4
# epoch  865 Training PSNR 21.761, estimated fx 913.8 fy 759.4
# epoch  866 Training PSNR 21.876, estimated fx 914.3 fy 758.8
# epoch  867 Training PSNR 21.920, estimated fx 913.0 fy 758.7
# epoch  868 Training PSNR 21.835, estimated fx 912.9 fy 760.7
# epoch  869 Training PSNR 21.841, estimated fx 913.5 fy 760.3
# epoch  870 Training PSNR 22.046, estimated fx 914.7 fy 761.4
# epoch  871 Training PSNR 22.024, estimated fx 913.6 fy 758.8
# epoch  872 Training PSNR 21.658, estimated fx 913.8 fy 761.9
# epoch  873 Training PSNR 21.679, estimated fx 915.2 fy 758.0
# epoch  874 Training PSNR 21.917, estimated fx 911.7 fy 759.9
# epoch  875 Training PSNR 22.046, estimated fx 915.3 fy 760.7
# epoch  876 Training PSNR 21.924, estimated fx 912.0 fy 760.2
# epoch  877 Training PSNR 21.910, estimated fx 913.5 fy 760.0
# epoch  878 Training PSNR 21.536, estimated fx 911.8 fy 759.6
# epoch  879 Training PSNR 21.873, estimated fx 915.5 fy 758.4
# epoch  880 Training PSNR 21.850, estimated fx 911.9 fy 760.0
# epoch  881 Training PSNR 21.939, estimated fx 913.2 fy 758.7
# epoch  882 Training PSNR 22.095, estimated fx 912.9 fy 761.4
# epoch  883 Training PSNR 21.971, estimated fx 913.9 fy 759.1
# epoch  884 Training PSNR 22.015, estimated fx 911.9 fy 761.8
# epoch  885 Training PSNR 22.059, estimated fx 914.4 fy 759.5
# epoch  886 Training PSNR 21.966, estimated fx 913.4 fy 761.3
# epoch  887 Training PSNR 21.770, estimated fx 914.7 fy 760.0
# epoch  888 Training PSNR 21.872, estimated fx 912.5 fy 759.4
# epoch  889 Training PSNR 21.950, estimated fx 912.1 fy 760.9
# epoch  890 Training PSNR 21.916, estimated fx 915.4 fy 759.0
# epoch  891 Training PSNR 22.037, estimated fx 910.5 fy 762.0
# epoch  892 Training PSNR 21.729, estimated fx 916.8 fy 759.4
# epoch  893 Training PSNR 21.639, estimated fx 910.7 fy 760.7
# epoch  894 Training PSNR 21.594, estimated fx 913.2 fy 760.8
# epoch  895 Training PSNR 21.829, estimated fx 911.1 fy 763.2
# epoch  896 Training PSNR 22.138, estimated fx 913.3 fy 760.4
# epoch  897 Training PSNR 22.165, estimated fx 911.4 fy 763.4
# epoch  898 Training PSNR 22.248, estimated fx 913.6 fy 761.1
# epoch  899 Training PSNR 22.157, estimated fx 910.8 fy 763.5
# epoch  900 Training PSNR 21.976, estimated fx 913.3 fy 760.8
# epoch  901 Training PSNR 22.084, estimated fx 911.9 fy 763.1
# epoch  902 Training PSNR 22.019, estimated fx 914.5 fy 759.9
# epoch  903 Training PSNR 22.078, estimated fx 911.8 fy 763.5
# epoch  904 Training PSNR 22.109, estimated fx 914.1 fy 759.0
# epoch  905 Training PSNR 22.333, estimated fx 911.7 fy 763.4
# epoch  906 Training PSNR 22.257, estimated fx 911.6 fy 760.5
# epoch  907 Training PSNR 22.075, estimated fx 913.2 fy 763.7
# epoch  908 Training PSNR 22.325, estimated fx 912.6 fy 760.8
# epoch  909 Training PSNR 22.357, estimated fx 912.7 fy 762.9
# epoch  910 Training PSNR 22.208, estimated fx 913.7 fy 761.5
# epoch  911 Training PSNR 22.175, estimated fx 912.7 fy 762.6
# epoch  912 Training PSNR 22.131, estimated fx 911.4 fy 759.4
# epoch  913 Training PSNR 21.916, estimated fx 916.5 fy 764.1
# epoch  914 Training PSNR 21.904, estimated fx 910.2 fy 761.7
# epoch  915 Training PSNR 21.926, estimated fx 914.6 fy 763.4
# epoch  916 Training PSNR 21.936, estimated fx 910.8 fy 762.5
# epoch  917 Training PSNR 21.968, estimated fx 912.5 fy 763.0
# epoch  918 Training PSNR 21.998, estimated fx 913.8 fy 761.5
# epoch  919 Training PSNR 22.012, estimated fx 914.4 fy 763.2
# epoch  920 Training PSNR 21.960, estimated fx 913.4 fy 764.2
# epoch  921 Training PSNR 22.148, estimated fx 913.6 fy 763.0
# epoch  922 Training PSNR 21.968, estimated fx 913.9 fy 764.4
# epoch  923 Training PSNR 22.015, estimated fx 913.7 fy 765.1
# epoch  924 Training PSNR 22.050, estimated fx 914.7 fy 763.8
# epoch  925 Training PSNR 22.243, estimated fx 913.3 fy 763.7
# epoch  926 Training PSNR 22.205, estimated fx 914.6 fy 762.9
# epoch  927 Training PSNR 22.151, estimated fx 913.4 fy 764.7
# epoch  928 Training PSNR 22.069, estimated fx 912.9 fy 763.3
# epoch  929 Training PSNR 22.145, estimated fx 914.3 fy 764.8
# epoch  930 Training PSNR 21.939, estimated fx 912.2 fy 763.8
# epoch  931 Training PSNR 22.344, estimated fx 912.6 fy 764.0
# epoch  932 Training PSNR 22.046, estimated fx 912.9 fy 763.3
# epoch  933 Training PSNR 22.294, estimated fx 912.9 fy 763.8
# epoch  934 Training PSNR 22.335, estimated fx 913.0 fy 763.7
# epoch  935 Training PSNR 22.202, estimated fx 912.2 fy 764.2
# epoch  936 Training PSNR 22.276, estimated fx 914.7 fy 764.3
# epoch  937 Training PSNR 21.990, estimated fx 913.4 fy 763.7
# epoch  938 Training PSNR 22.184, estimated fx 913.1 fy 764.8
# epoch  939 Training PSNR 22.014, estimated fx 914.3 fy 764.3
# epoch  940 Training PSNR 22.181, estimated fx 912.4 fy 764.0
# epoch  941 Training PSNR 22.013, estimated fx 913.4 fy 764.9
# epoch  942 Training PSNR 22.042, estimated fx 913.2 fy 766.1
# epoch  943 Training PSNR 21.921, estimated fx 913.2 fy 764.2
# epoch  944 Training PSNR 22.142, estimated fx 913.9 fy 763.9
# epoch  945 Training PSNR 22.084, estimated fx 912.4 fy 766.3
# epoch  946 Training PSNR 22.059, estimated fx 913.1 fy 763.9
# epoch  947 Training PSNR 22.115, estimated fx 913.2 fy 766.8
# epoch  948 Training PSNR 22.104, estimated fx 912.3 fy 764.7
# epoch  949 Training PSNR 22.154, estimated fx 913.7 fy 763.6
# epoch  950 Training PSNR 21.832, estimated fx 913.7 fy 766.0
# epoch  951 Training PSNR 22.078, estimated fx 913.0 fy 764.0
# epoch  952 Training PSNR 22.242, estimated fx 913.0 fy 765.4
# epoch  953 Training PSNR 22.092, estimated fx 914.6 fy 763.5
# epoch  954 Training PSNR 22.332, estimated fx 911.7 fy 766.2
# epoch  955 Training PSNR 22.139, estimated fx 913.0 fy 765.3
# epoch  956 Training PSNR 22.232, estimated fx 911.7 fy 766.6
# epoch  957 Training PSNR 21.954, estimated fx 914.4 fy 763.7
# epoch  958 Training PSNR 22.058, estimated fx 910.5 fy 768.4
# epoch  959 Training PSNR 22.443, estimated fx 916.8 fy 763.0
# epoch  960 Training PSNR 21.991, estimated fx 911.2 fy 767.0
# epoch  961 Training PSNR 22.132, estimated fx 916.2 fy 762.5
# epoch  962 Training PSNR 21.994, estimated fx 908.7 fy 765.9
# epoch  963 Training PSNR 22.140, estimated fx 916.3 fy 763.2
# epoch  964 Training PSNR 21.935, estimated fx 909.0 fy 766.5
# epoch  965 Training PSNR 22.220, estimated fx 917.9 fy 763.7
# epoch  966 Training PSNR 22.324, estimated fx 909.4 fy 767.8
# epoch  967 Training PSNR 22.017, estimated fx 916.3 fy 764.3
# epoch  968 Training PSNR 21.973, estimated fx 908.8 fy 768.8
# epoch  969 Training PSNR 22.076, estimated fx 913.3 fy 763.0
# epoch  970 Training PSNR 22.339, estimated fx 911.1 fy 767.1
# epoch  971 Training PSNR 22.327, estimated fx 914.9 fy 764.7
# epoch  972 Training PSNR 22.324, estimated fx 911.7 fy 767.2
# epoch  973 Training PSNR 22.073, estimated fx 914.2 fy 764.8
# epoch  974 Training PSNR 21.933, estimated fx 911.5 fy 766.4
# epoch  975 Training PSNR 22.252, estimated fx 914.0 fy 765.6
# epoch  976 Training PSNR 22.199, estimated fx 912.3 fy 768.5
# epoch  977 Training PSNR 22.078, estimated fx 912.5 fy 763.8
# epoch  978 Training PSNR 21.949, estimated fx 911.9 fy 767.1
# epoch  979 Training PSNR 22.071, estimated fx 913.3 fy 765.4
# epoch  980 Training PSNR 22.257, estimated fx 912.2 fy 765.7
# epoch  981 Training PSNR 22.175, estimated fx 912.8 fy 768.5
# epoch  982 Training PSNR 21.832, estimated fx 912.8 fy 765.5
# epoch  983 Training PSNR 22.293, estimated fx 911.6 fy 767.7
# epoch  984 Training PSNR 22.241, estimated fx 913.4 fy 766.7
# epoch  985 Training PSNR 22.429, estimated fx 911.1 fy 767.0
# epoch  986 Training PSNR 22.261, estimated fx 913.4 fy 766.8
# epoch  987 Training PSNR 22.102, estimated fx 911.6 fy 765.6
# epoch  988 Training PSNR 22.088, estimated fx 913.3 fy 766.1
# epoch  989 Training PSNR 21.973, estimated fx 912.6 fy 769.0
# epoch  990 Training PSNR 22.095, estimated fx 913.7 fy 768.0
# epoch  991 Training PSNR 22.330, estimated fx 911.8 fy 767.4
# epoch  992 Training PSNR 22.043, estimated fx 912.6 fy 766.2
# epoch  993 Training PSNR 22.176, estimated fx 910.5 fy 768.9
# epoch  994 Training PSNR 22.098, estimated fx 914.0 fy 766.2
# epoch  995 Training PSNR 22.148, estimated fx 911.8 fy 768.3
# epoch  996 Training PSNR 22.196, estimated fx 913.7 fy 767.3
# epoch  997 Training PSNR 22.165, estimated fx 909.9 fy 768.3
# epoch  998 Training PSNR 22.084, estimated fx 913.4 fy 767.0
# epoch  999 Training PSNR 22.189, estimated fx 911.9 fy 768.2
# Training finished.

# %%
output_folder = 'enhanced_images'
os.makedirs(output_folder, exist_ok=True)

rendered_img_list = []  # List to store rendered images

with torch.no_grad():
    nerf_model.eval()
    fxfy = focal_net()

    optimised_poses = torch.stack([pose_param_net(i) for i in range(N_IMGS)])

    print('NeRF trained in {0:d} x {1:d} for {2:d} epochs'.format(H, W, N_EPOCH))

    t_vals = torch.linspace(ray_params.NEAR, ray_params.FAR, ray_params.N_SAMPLE, device='cuda')

    ray_dir_cam = comp_ray_dir_cam_fxfy(H, W, fxfy[0], fxfy[1])

    for i in range(N_IMGS):
        c2w = optimised_poses[i].cuda()

        split_size = len(ray_dir_cam) // N_IMGS
        rays_dir_cam_split_rows = ray_dir_cam.split(split_size, dim=0)
        # rays_dir_cam_split_rows = ray_dir_cam.split(16, dim=0)  # Split the rays into chunks

        enh_img_list, enh_depth_list = [], []

        for rays_dir_rows in rays_dir_cam_split_rows:
            render_result = model_render_image(c2w, rays_dir_rows, t_vals, ray_params,
                                               H, W, fxfy, nerf_model, perturb_t=False, sigma_noise_std=0.0)
            rgb_rendered_rows = render_result['rgb']  # (num_rows_eval_img, W, 3)
            depth_map = render_result['depth_map']  # (num_rows_eval_img, W)

            enh_img_list.append(rgb_rendered_rows)
            enh_depth_list.append(depth_map)

        # Concatenate rendered images and depth maps
        rendered_img = torch.cat(enh_img_list, dim=0)  # (H * num_images, W, 3)
        rendered_depth = torch.cat(enh_depth_list, dim=0)  # (H * num_images, W)

        # Convert to numpy arrays for visualization
        rendered_img_np = (rendered_img.cpu().numpy() * 255).astype(np.uint8)
        rendered_depth_np = (rendered_depth.cpu().numpy() * 200).astype(np.uint8)

        # Save the enhanced images
        image_filename = f'image_{i:03d}.png'
        imageio.imwrite(os.path.join(output_folder, image_filename), rendered_img_np)

        # Append rendered image to the list
        rendered_img_list.append(rendered_img_np)

print('Enhanced images saved.')

# Convert the list of rendered images to a numpy array for creating GIF
rendered_img_array = np.array(rendered_img_list)
# Out:
# NeRF trained in 270 x 480 for 2000 epochs
# Enhanced images saved.

# %%
import imageio

# Define the output file path for the GIF
gif_output_path = 'rendered_images.gif'

# Create the GIF using imageio
imageio.mimsave(gif_output_path, rendered_img_list, duration=0.1)  # Adjust duration as needed

print(f'GIF created and saved at: {gif_output_path}')
# Out:
# GIF created and saved at: rendered_images.gif

# %%
Image(open(os.path.join('rendered_images.gif'), 'rb').read())

# %%
with torch.no_grad():
   nerf_model.eval()
   fxfy = focal_net()

   optimised_poses = torch.stack([pose_param_net(i) for i in range(N_IMGS)])
   c2w = c2w.to('cuda')

   print('NeRF trained in {0:d} x {1:d} for {2:d} epochs'.format(H, W, N_EPOCH))

   t_vals = torch.linspace(ray_params.NEAR, ray_params.FAR, ray_params.N_SAMPLE, device='cuda')

   ray_dir_cam = comp_ray_dir_cam_fxfy(H, W, fxfy[0], fxfy[1])
   rays_dir_cam_split_rows = ray_dir_cam.split(10, dim=0)  # input 10 rows each time

   enh_img_list, enh_depth_list = [], []
   rendered_img = []
   rendered_depth = []
   for rays_dir_rows in rays_dir_cam_split_rows:
         render_result = model_render_image(c2w, rays_dir_rows, t_vals, ray_params,
                                           H, W, fxfy, nerf_model, perturb_t=False, sigma_noise_std=0.0)
         rgb_rendered_rows = render_result['rgb']  # (num_rows_eval_img, W, 3)
         depth_map = render_result['depth_map']  # (num_rows_eval_img, W)

         rendered_img.append(rgb_rendered_rows)
         rendered_depth.append(depth_map)

   rendered_img = torch.cat(rendered_img, dim=0)  # (H, W, 3)
   rendered_depth = torch.cat(rendered_depth, dim=0)  # (H, W)

   enh_img_list.append(rendered_img)
   enh_depth_list.append(rendered_depth)


   print(' Enhanced view rendering done. Saving to GIF images...')
   enh_img_list = (torch.stack(enh_img_list) * 255).cpu().numpy().astype(np.uint8)
   enh_depth_list = (torch.stack(enh_depth_list) * 200).cpu().numpy().astype(np.uint8)
   os.makedirs('nvs_results', exist_ok=True)
   imageio.mimwrite(os.path.join('nvs_results', scene_name + '_img.gif'), enh_img_list, fps=30)
   imageio.mimwrite(os.path.join('nvs_results', scene_name + '_depth.gif'), enh_depth_list, fps=30)
   print('GIF images saved.')

# %% [markdown]
# ## Step 5: Novel View Synthesis

# %%
from nerfmm.utils.pose_utils import create_spiral_poses

resize_ratio = 4
with torch.no_grad():
    optimised_poses = torch.stack([pose_param_net(i) for i in range(N_IMGS)])
    radii = np.percentile(np.abs(optimised_poses.cpu().numpy()[:, :3, 3]), q=50, axis=0)  # (3,)
    spiral_c2ws = create_spiral_poses(radii, focus_depth=3.5, n_poses=30, n_circle=1)
    spiral_c2ws = torch.from_numpy(spiral_c2ws).float()  # (N, 3, 4)


    fxfy = focal_net()
    novel_fxfy = fxfy / resize_ratio
    novel_H, novel_W = H // resize_ratio, W // resize_ratio

    print('NeRF trained in {0:d} x {1:d} for {2:d} epochs'.format(H, W, N_EPOCH))
    print('Rendering novel views in {0:d} x {1:d}'.format(novel_H, novel_W))

    novel_img_list, novel_depth_list = [], []
    for i in tqdm(range(spiral_c2ws.shape[0]), desc='novel view rendering'):
        novel_img, novel_depth = render_novel_view(spiral_c2ws[i], novel_H, novel_W, novel_fxfy,
                                                   ray_params, nerf_model)
        novel_img_list.append(novel_img)
        novel_depth_list.append(novel_depth)

    print('Novel view rendering done. Saving to GIF images...')
    novel_img_list = (torch.stack(novel_img_list) * 255).cpu().numpy().astype(np.uint8)
    novel_depth_list = (torch.stack(novel_depth_list) * 200).cpu().numpy().astype(np.uint8)  # depth is always in 0 to 1 in NDC

    os.makedirs('nvs_results', exist_ok=True)
    imageio.mimwrite(os.path.join('nvs_results', scene_name + '_img.gif'), novel_img_list, fps=30)
    imageio.mimwrite(os.path.join('nvs_results', scene_name + '_depth.gif'), novel_depth_list, fps=30)
    print('GIF images saved.')
# Out:
# NeRF trained in 756 x 1008 for 1000 epochs
# Rendering novel views in 189 x 252
# novel view rendering:   0%|          | 0/30 [00:00<?, ?it/s]
# Novel view rendering done. Saving to GIF images...

# %%
Image(open(os.path.join('nvs_results', scene_name + '_img.gif'), 'rb').read())

# %%
import shutil
# Define the local folder path within Colab
local_folder_path = "/content/novel_views_generated"

print('Novel view rendering done. Saving images...')

# Create the local folder
os.makedirs(local_folder_path, exist_ok=True)

for i in range(30):
    plt.imshow(novel_img_list[i])
    plt.savefig(os.path.join(local_folder_path, f'novel_view_{i+1}.png'))
    plt.clf()  # Clear the current figure to avoid overlapping images

print(f'Novel views saved as images in {local_folder_path}.')

# ... (remaining code)

# Create a zip archive
shutil.make_archive("/content/novel_views_generated", 'zip', local_folder_path)

# Move the zip archive to the current working directory
shutil.move("/content/novel_views_generated.zip", "/content/novel_views_generated.zip")

print('Zip archive created. Downloading...')

# Provide a link to download the zip archive
from google.colab import files

files.download("/content/novel_views_generated.zip")
# Out:
# Novel view rendering done. Saving images...
# Novel views saved as images in /content/novel_views_generated.
# Zip archive created. Downloading...

# %%
Image(open(os.path.join('nvs_results', scene_name + '_depth.gif'), 'rb').read())

# %% [markdown]
# ## Step 6: Visualise Camera Poses 📷

# %%
# %matplotlib inline
from matplotlib import animation
from IPython.display import HTML

fig = plt.figure(figsize=(6, 6))
ax0 = plt.subplot(111)
ax0.set_xlim((-0.5, 0.5))
ax0.set_ylim((-0.5, 0.5))
ax0.set_xlabel('X')
ax0.set_ylabel('Y')
ax0.grid(ls='--', color='0.7')

title = ax0.set_title('')
traj_line, = ax0.plot([], [], c='blue', ls='-', marker='^', linewidth=0.7, markersize=4)

def drawframe(fr_id):
    """
    :param fr_id: frame id
    :param poses: (N_img, 3) camera positions
    """
    poses = pose_history[fr_id]
    traj_line.set_data(poses[:, 0], poses[:, 1])
    title.set_text('epoch {0:4d}'.format(fr_id))
    return (traj_line,)

anim = animation.FuncAnimation(fig, drawframe, frames=N_EPOCH, interval=100)

plt.close(anim._fig)
HTML(anim.to_html5_video())
# Out:
# <video width="600" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...
